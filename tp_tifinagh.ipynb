# %% [markdown]
# # **Multiclass Neural Network for Tifinagh Character Recognition**
#
# This notebook implements a multilayer perceptron (MLP) to classify handwritten Tifinagh characters from the AMHCD dataset (28,182 images, 33 classes). It includes data preprocessing, model training, hyperparameter tuning, cross-validation, and evaluation, with bonus features: L2 regularization, Adam optimizer, K-fold cross-validation, and data augmentation.

# %% [markdown]
# ## **1.Imports and Setup**
# Import required libraries and set random seed for reproducibility.

# %%
import os
import cv2
import sys
import time
import random
import zipfile
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ## **2.Activation Functions**
# Define ReLU and Softmax activations for the MLP.

# %%
# Activation Functions
def relu(x):
    """ReLU activation: max(0, x)"""
    assert isinstance(x, np.ndarray), "Input to ReLU must be a numpy array"
    result = np.maximum(0, x)
    assert np.all(result >= 0), "ReLU output must be non-negative"
    return result

def relu_derivative(x):
    """Derivative of ReLU: 1 if x > 0, else 0"""
    assert isinstance(x, np.ndarray), "Input to ReLU derivative must be a numpy array"
    result = np.where(x > 0, 1, 0)
    assert np.all((result == 0) | (result == 1)), "ReLU derivative must be 0 or 1"
    return result

def softmax(x):
    """Softmax activation: exp(x) / sum(exp(x))"""
    assert isinstance(x, np.ndarray), "Input to softmax must be a numpy array"
    exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
    result = exp_x / np.sum(exp_x, axis=1, keepdims=True)
    assert np.all((result >= 0) & (result <= 1)), "Softmax output must be in [0,1]"
    assert np.allclose(np.sum(result, axis=1), 1), "Softmax output must sum to 1"
    return result

# %% [markdown]
# ## **3.Data Augmentation and Preprocessing**
# Functions for augmenting images (rotation, translation) and preprocessing (grayscale, resize, normalize).

# %%
# Data Augmentation
def augment_image(image, max_rotation=10, max_translation=3):
    """Apply random rotation and translation to a 32x32 grayscale image"""
    assert image.shape == (32, 32), "Image must be 32x32"
    angle = np.random.uniform(-max_rotation, max_rotation)
    M = cv2.getRotationMatrix2D((16, 16), angle, 1.0)
    rotated = cv2.warpAffine(image, M, (32, 32), borderMode=cv2.BORDER_REPLICATE)
    tx = np.random.uniform(-max_translation, max_translation)
    ty = np.random.uniform(-max_translation, max_translation)
    M = np.float32([[1, 0, tx], [0, 1, ty]])
    translated = cv2.warpAffine(rotated, M, (32, 32), borderMode=cv2.BORDER_REPLICATE)
    return translated.flatten()

# Image Preprocessing
def load_and_preprocess_image(image_path, data_dir, target_size=(32, 32)):
    """Load and preprocess image: grayscale, resize, normalize"""
    full_path = os.path.join(data_dir, image_path)
    assert os.path.exists(full_path), f"Image not found: {full_path}"
    img = cv2.imread(full_path, cv2.IMREAD_GRAYSCALE)
    assert img is not None, f"Failed to load image: {full_path}"
    img = cv2.resize(img, target_size)
    img = img.astype(np.float32) / 255.0
    return img.flatten()

# %% [markdown]
# ## **4.Visualization**
# Function to display sample images per Tifinagh class.

# %%
# Visualization
def display_sample_images_from_paths(labels_df, data_dir, path_column='image_path', label_column='label',
                                     num_samples=33, samples_per_row=11, random_state=83):
    """Display a grid of sample grayscale images, one per class"""
    assert path_column in labels_df.columns, f"Missing column: {path_column}"
    assert label_column in labels_df.columns, f"Missing column: {label_column}"

    rng = np.random.default_rng(random_state)
    unique_labels = labels_df[label_column].unique()
    num_samples = min(num_samples, len(unique_labels))
    selected_indices = [rng.choice(labels_df[labels_df[label_column] == lbl].index)
                        for lbl in rng.choice(unique_labels, size=num_samples, replace=False)]
    selected_df = labels_df.loc[selected_indices].sort_values(by=label_column)

    num_rows = (num_samples + samples_per_row - 1) // samples_per_row
    fig, axes = plt.subplots(num_rows, samples_per_row, figsize=(samples_per_row * 2, num_rows * 3))
    axes = axes.ravel()

    for i, (path, label) in enumerate(zip(selected_df[path_column], selected_df[label_column])):
        try:
            img = Image.open(os.path.join(data_dir, path))
            axes[i].imshow(img, cmap='gray')
            axes[i].set_title(f"Label: {label}", fontsize=17)
            axes[i].axis('off')
        except Exception as e:
            print(f"Error loading {path}: {e}")
            axes[i].set_title("Error")
            axes[i].axis('off')

    for ax in axes[num_samples:]:
        ax.axis('off')

    plt.tight_layout()
    return fig

# %% [markdown]
# ## **5.Neural Network Implementation**
# MLP class with forward propagation, backpropagation, and training logic.

# %%
# Neural Network Class
class MulticlassNeuralNetwork:
    def __init__(self, layer_sizes, learning_rate=0.01, l2_lambda=0.01, optimizer='sgd', beta1=0.9, beta2=0.999, epsilon=1e-8):
        """Initialize MLP with specified architecture and parameters"""
        assert len(layer_sizes) >= 2, "At least 2 layers required"
        assert all(size > 0 for size in layer_sizes), "Layer sizes must be positive"
        self.layer_sizes = layer_sizes
        self.learning_rate = learning_rate
        self.l2_lambda = l2_lambda
        self.optimizer = optimizer.lower()
        self.beta1, self.beta2, self.epsilon = beta1, beta2, epsilon
        self.weights = []
        self.biases = []
        self.m_weights, self.v_weights = [], []
        self.m_biases, self.v_biases = [], []
        self.t = 0

        # He initialization
        np.random.seed(42)
        for i in range(len(layer_sizes) - 1):
            w = np.random.randn(layer_sizes[i], layer_sizes[i + 1]) * np.sqrt(2 / layer_sizes[i])
            b = np.zeros((1, layer_sizes[i + 1]))
            self.weights.append(w)
            self.biases.append(b)
            self.m_weights.append(np.zeros_like(w))
            self.v_weights.append(np.zeros_like(w))
            self.m_biases.append(np.zeros_like(b))
            self.v_biases.append(np.zeros_like(b))

    def forward(self, X):
        """Forward propagation"""
        self.z_values, self.activations = [], [X]
        for i in range(len(self.weights) - 1):
            Z = np.dot(self.activations[-1], self.weights[i]) + self.biases[i]
            self.z_values.append(Z)
            self.activations.append(relu(Z))
        Z = np.dot(self.activations[-1], self.weights[-1]) + self.biases[-1]
        self.z_values.append(Z)
        output = softmax(Z)
        self.activations.append(output)
        return output

    def compute_loss(self, y_true, y_pred):
        """Cross-entropy loss with L2 regularization"""
        m = y_true.shape[0]
        y_pred_clipped = np.clip(y_pred, 1e-15, 1 - 1e-15)
        cross_entropy = -np.sum(y_true * np.log(y_pred_clipped)) / m
        l2_term = (self.l2_lambda / (2 * m)) * sum(np.sum(np.square(W)) for W in self.weights)
        total_loss = cross_entropy + l2_term
        assert not np.isnan(total_loss), "Loss is NaN"
        return total_loss

    def compute_accuracy(self, y_true, y_pred):
        """Compute accuracy"""
        predictions = np.argmax(y_pred, axis=1)
        true_labels = np.argmax(y_true, axis=1)
        return np.mean(predictions == true_labels)

    def backward(self, X, y):
        """Backpropagation"""
        m = X.shape[0]
        self.d_weights = [np.zeros_like(w) for w in self.weights]
        self.d_biases = [np.zeros_like(b) for b in self.biases]
        dZ = self.activations[-1] - y
        self.d_weights[-1] = (np.dot(self.activations[-2].T, dZ) + self.l2_lambda * self.weights[-1]) / m
        self.d_biases[-1] = np.sum(dZ, axis=0, keepdims=True) / m
        dA_prev = dZ
        for i in range(len(self.weights) - 2, -1, -1):
            dA = np.dot(dA_prev, self.weights[i + 1].T)
            dZ = dA * relu_derivative(self.z_values[i])
            self.d_weights[i] = (np.dot(self.activations[i].T, dZ) + self.l2_lambda * self.weights[i]) / m
            self.d_biases[i] = np.sum(dZ, axis=0, keepdims=True) / m
            dA_prev = dZ

    def update_parameters(self):
        """Update parameters using SGD or Adam"""
        if self.optimizer == 'sgd':
            for i in range(len(self.weights)):
                self.weights[i] -= self.learning_rate * self.d_weights[i]
                self.biases[i] -= self.learning_rate * self.d_biases[i]
        elif self.optimizer == 'adam':
            self.t += 1
            for i in range(len(self.weights)):
                self.m_weights[i] = self.beta1 * self.m_weights[i] + (1 - self.beta1) * self.d_weights[i]
                self.v_weights[i] = self.beta2 * self.v_weights[i] + (1 - self.beta2) * (self.d_weights[i] ** 2)
                self.m_biases[i] = self.beta1 * self.m_biases[i] + (1 - self.beta1) * self.d_biases[i]
                self.v_biases[i] = self.beta2 * self.v_biases[i] + (1 - self.beta2) * (self.d_biases[i] ** 2)
                m_w_hat = self.m_weights[i] / (1 - self.beta1 ** self.t)
                v_w_hat = self.v_weights[i] / (1 - self.beta2 ** self.t)
                m_b_hat = self.m_biases[i] / (1 - self.beta1 ** self.t)
                v_b_hat = self.v_biases[i] / (1 - self.beta2 ** self.t)
                self.weights[i] -= self.learning_rate * m_w_hat / (np.sqrt(v_w_hat) + self.epsilon)
                self.biases[i] -= self.learning_rate * m_b_hat / (np.sqrt(v_b_hat) + self.epsilon)

    def train(self, X, y, X_val, y_val, epochs=100, batch_size=100, augment=False, early_stopping=True, verbose=1):
        """Train the MLP"""
        train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
        best_val_loss = np.inf
        best_weights = [w.copy() for w in self.weights]
        best_biases = [b.copy() for b in self.biases]
        patience, patience_counter = 10, 0

        for epoch in range(epochs):
            indices = np.random.permutation(X.shape[0])
            X_shuffled, y_shuffled = X[indices], y[indices]
            epoch_loss = 0
            for i in range(0, X.shape[0], batch_size):
                X_batch = X_shuffled[i:i + batch_size]
                y_batch = y_shuffled[i:i + batch_size]
                if augment:
                    X_batch = np.array([augment_image(img.reshape(32, 32)) for img in X_batch])
                outputs = self.forward(X_batch)
                epoch_loss += self.compute_loss(y_batch, outputs)
                self.backward(X_batch, y_batch)
                self.update_parameters()

            train_pred = self.forward(X)
            val_pred = self.forward(X_val)
            train_loss = epoch_loss / (X.shape[0] // batch_size)
            val_loss = self.compute_loss(y_val, val_pred)
            train_accuracy = self.compute_accuracy(y, train_pred)
            val_accuracy = self.compute_accuracy(y_val, val_pred)

            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accuracies.append(train_accuracy)
            val_accuracies.append(val_accuracy)

            if early_stopping:
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    best_weights = [w.copy() for w in self.weights]
                    best_biases = [b.copy() for b in self.biases]
                    patience_counter = 0
                else:
                    patience_counter += 1
                    if patience_counter >= patience:
                        if verbose >= 1:
                            print(f"Early stopping at epoch {epoch + 1}")
                        self.weights = best_weights
                        self.biases = best_biases
                        break

            if verbose >= 1 and (epoch % 10 == 0 or epoch == epochs - 1):
                print(f"Epoch {epoch + 1:03d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
                      f"Train Acc: {train_accuracy:.4f} | Val Acc: {val_accuracy:.4f}")

        return train_losses, val_losses, train_accuracies, val_accuracies

    def predict(self, X):
        """Predict class labels"""
        outputs = self.forward(X)
        return np.argmax(outputs, axis=1)

# %% [markdown]
# ## **6.K-Fold Cross-Validation**
# Function for K-fold cross-validation to evaluate model robustness.

# %%
# K-Fold Cross-Validation
def k_fold_cross_validation(X, y_one_hot, layer_sizes, k=5, epochs=100, batch_size=100, learning_rate=0.01,
                            l2_lambda=0.01, optimizer='sgd', augment=False, verbose=1):
    """Perform K-fold cross-validation"""
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    fold_train_losses, fold_val_losses = [], []
    fold_train_accuracies, fold_val_accuracies = [], []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        if verbose >= 1:
            print(f"\nFold {fold + 1}/{k}")
        start_time = time.time()
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y_one_hot[train_idx], y_one_hot[val_idx]
        nn = MulticlassNeuralNetwork(layer_sizes, learning_rate, l2_lambda, optimizer)
        train_losses, val_losses, train_accuracies, val_accuracies = nn.train(
            X_train, y_train, X_val, y_val, epochs, batch_size, augment, early_stopping=True, verbose=verbose
        )
        fold_train_losses.append(train_losses)
        fold_val_losses.append(val_losses)
        fold_train_accuracies.append(train_accuracies)
        fold_val_accuracies.append(val_accuracies)
        if verbose >= 1:
            print(f"Fold {fold + 1} completed in {time.time() - start_time:.2f} seconds")

    # Pad shorter lists to max length
    max_len = max(len(lst) for lst in fold_train_losses)
    for lst in fold_train_losses + fold_val_losses + fold_train_accuracies + fold_val_accuracies:
        lst.extend([lst[-1]] * (max_len - len(lst)))

    avg_train_losses = np.mean(fold_train_losses, axis=0)
    avg_val_losses = np.mean(fold_val_losses, axis=0)
    avg_train_accuracies = np.mean(fold_train_accuracies, axis=0)
    avg_val_accuracies = np.mean(fold_val_accuracies, axis=0)

    if verbose >= 1:
        print(f"\nCross-Validation Summary: Avg Val Accuracy: {avg_val_accuracies[-1]:.4f}")
    return avg_train_losses, avg_val_losses, avg_train_accuracies, avg_val_accuracies

# %% [markdown]
# ## **7.Dataset Loading and Preprocessing**
# Load AMHCD dataset, preprocess images, encode labels, and split data.

# %% [markdown]
# ### **7.1. Extracting & Loading AMHCD DataSet**

# %%
# Dataset Loading
zip_path = "/content/amhcd-data-64.zip"
extract_path = "/content/amhcd-data-64"


if not os.path.exists(extract_path):
    if os.path.exists(zip_path):
        try:
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                zip_ref.extractall(os.path.dirname(extract_path))
                print(f"Extracted dataset to {extract_path}")
        except zipfile.BadZipFile:
            print(f"Error: Corrupted ZIP file at {zip_path}")
    else:
        print(f"ZIP file not found at {zip_path}")
else:
    print(f"Dataset already exists at {extract_path}")

# Path to use later
data_dir = extract_path
# Out:
# Extracted dataset to /content/amhcd-data-64

# %%
labels_csv_path = os.path.join(data_dir, "labels-map.csv")
labels_df = pd.read_csv(labels_csv_path, names=['image_path', 'label'])


assert not labels_df.empty, "No data loaded. Check dataset files."
labels_df['image_path'] = labels_df['image_path'].apply(lambda x: x.replace('./images-data-64/', '') if isinstance(x, str) else x)

# %%
# Debugging: Print sample paths
print("Sample image paths:")
for path in labels_df['image_path'].head(5):
    full_path = os.path.join(data_dir, path)
    print(f"{full_path} -> Exists: {os.path.exists(full_path)}")

print(f"\nLoaded {len(labels_df)} samples with {labels_df['label'].nunique ()} unique classes .")
# Out:
# Sample image paths:
# /content/amhcd-data-64/tifinagh-images/ya/tifinagh_1.jpeg -> Exists: True
# /content/amhcd-data-64/tifinagh-images/ya/tifinagh_2.jpeg -> Exists: True
# /content/amhcd-data-64/tifinagh-images/ya/tifinagh_3.jpeg -> Exists: True
# /content/amhcd-data-64/tifinagh-images/ya/tifinagh_4.jpeg -> Exists: True
# /content/amhcd-data-64/tifinagh-images/ya/tifinagh_5.jpeg -> Exists: True
#
# Loaded 28182 samples with 33 unique classes .

# %%
class_counts = labels_df['label'].value_counts()
print("Class distribution summary:")
print(f"Min: {class_counts.min()}, Max: {class_counts.max()}, Mean: {class_counts.mean():.2f}")
# Out:
# Class distribution summary:
# Min: 854, Max: 854, Mean: 854.00

# %%
print("Label encoding ...")
# Encode labels
label_encoder = LabelEncoder()
labels_df['label_encoded'] = label_encoder.fit_transform(labels_df['label'])
num_classes = len(label_encoder.classes_)

print("==================== Data with label encoded: ======================")
print(labels_df)
# Out:
# Label encoding ...
# ==================== Data with label encoded: ======================
#                                      image_path label  label_encoded
# 0            tifinagh-images/ya/tifinagh_1.jpeg     ⴰ              0
# 1            tifinagh-images/ya/tifinagh_2.jpeg     ⴰ              0
# 2            tifinagh-images/ya/tifinagh_3.jpeg     ⴰ              0
# 3            tifinagh-images/ya/tifinagh_4.jpeg     ⴰ              0
# 4            tifinagh-images/ya/tifinagh_5.jpeg     ⴰ              0
# ...                                         ...   ...            ...
# 28177  tifinagh-images/yazz/tifinagh_28178.jpeg     ⵥ             32
# 28178  tifinagh-images/yazz/tifinagh_28179.jpeg     ⵥ             32
# 28179  tifinagh-images/yazz/tifinagh_28180.jpeg     ⵥ             32
# 28180  tifinagh-images/yazz/tifinagh_28181.jpeg     ⵥ             32
# 28181  tifinagh-images/yazz/tifinagh_28182.jpeg     ⵥ             32
#
# [28182 rows x 3 columns]

# %%
print(f"Class distribution:")
# print(labels_df['label'].value_counts())
labels_df[['label', 'label_encoded']].value_counts()
# Out:
# Class distribution:
# label  label_encoded
# ⴰ      0                854
# ⴱ      1                854
# ⴳ      2                854
# ⴳⵯ     3                854
# ⴷ      4                854
# ⴹ      5                854
# ⴻ      6                854
# ⴼ      7                854
# ⴽ      8                854
# ⴽⵯ     9                854
# ⵀ      10               854
# ⵃ      11               854
# ⵄ      12               854
# ⵅ      13               854
# ⵇ      14               854
# ⵉ      15               854
# ⵊ      16               854
# ⵍ      17               854
# ⵎ      18               854
# ⵏ      19               854
# ⵓ      20               854
# ⵔ      21               854
# ⵕ      22               854
# ⵖ      23               854
# ⵙ      24               854
# ⵚ      25               854
# ⵛ      26               854
# ⵜ      27               854
# ⵟ      28               854
# ⵡ      29               854
# ⵢ      30               854
# ⵣ      31               854
# ⵥ      32               854
# Name: count, dtype: int64

# %%
# Load images
X = np.array([load_and_preprocess_image(path, data_dir) for path in labels_df['image_path']])
y = labels_df['label_encoded'].values

# Verify dimensions
assert X.shape[0] == y.shape[0], "Mismatch between number of images and labels"
assert X.shape[1] == 32 * 32, f"Expected flattened image size of {32 * 32}, got {X.shape[1]}"

# %%
fig = display_sample_images_from_paths(labels_df, data_dir)
plt.savefig('sample_images.png')
#plt.close()

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42)

one_hot_encoder = OneHotEncoder(sparse_output=False)
y_train_one_hot = one_hot_encoder.fit_transform(y_train.reshape(-1, 1))
y_val_one_hot = one_hot_encoder.transform(y_val.reshape(-1, 1))
y_test_one_hot = one_hot_encoder.transform(y_test.reshape(-1, 1))
print(f"Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
# Out:
# Train: 16908, Val: 5637, Test: 5637

# %% [markdown]
# # **8.Hyperparameter Tuning**

# %%
layer_sizes = [32 * 32, 64, 32, num_classes]
param_distributions = {
    'learning_rate': [0.01, 0.001],
    'l2_lambda': [0.01, 0.001],
    'batch_size': [64, 32],
    'optimizer': ['adam', 'sgd']
}

n_iter = 16

# All possible combinations
keys = list(param_distributions.keys())
all_combinations = [
    dict(zip(keys, values))
    for values in itertools.product(*param_distributions.values())
]

# Shuffle and pick n_iter unique combinations
random.shuffle(all_combinations)
param_combinations = all_combinations[:n_iter]

results = []
best_val_accuracy = 0
best_params = None

# %%
# ===================== Random Search + CV Loop =======================

for i in range(n_iter):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i + 1}/{n_iter}: {params}")
    avg_train_losses, avg_val_losses, avg_train_accuracies, avg_val_accuracies = k_fold_cross_validation(
        X_train, y_train_one_hot, layer_sizes, k=5, epochs=100, **params, augment=True, verbose=1
    )
    final_val_accuracy = avg_val_accuracies[-1]
    results.append({'trial': i + 1, 'params': params, 'final_val_accuracy': final_val_accuracy})
    if final_val_accuracy > best_val_accuracy:
        best_val_accuracy = final_val_accuracy
        best_params = params

print("\n======================================== Random Search's result: ==================================")
print(f"\nBest parameters: {best_params}")
print(f"Best validation accuracy: {best_val_accuracy:.4f}")
# Out:
# Trial 1/16: {'learning_rate': 0.01, 'l2_lambda': 0.01, 'batch_size': 64, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5190 | Val Loss: 3.4426 | Train Acc: 0.0651 | Val Acc: 0.0642
# Epoch 011 | Train Loss: 2.8004 | Val Loss: 2.4789 | Train Acc: 0.3076 | Val Acc: 0.2939
# Epoch 021 | Train Loss: 2.2980 | Val Loss: 1.9369 | Train Acc: 0.4397 | Val Acc: 0.4299
# Epoch 031 | Train Loss: 1.9961 | Val Loss: 1.6413 | Train Acc: 0.5211 | Val Acc: 0.5171
# Epoch 041 | Train Loss: 1.7987 | Val Loss: 1.4620 | Train Acc: 0.5670 | Val Acc: 0.5789
# Epoch 051 | Train Loss: 1.6391 | Val Loss: 1.3633 | Train Acc: 0.5866 | Val Acc: 0.5837
# Epoch 061 | Train Loss: 1.5227 | Val Loss: 1.2123 | Train Acc: 0.6475 | Val Acc: 0.6372
# Epoch 071 | Train Loss: 1.4198 | Val Loss: 1.1280 | Train Acc: 0.6661 | Val Acc: 0.6659
# Epoch 081 | Train Loss: 1.3572 | Val Loss: 1.0459 | Train Acc: 0.6957 | Val Acc: 0.6863
# Epoch 091 | Train Loss: 1.2783 | Val Loss: 1.0014 | Train Acc: 0.7097 | Val Acc: 0.6957
# Epoch 100 | Train Loss: 1.2249 | Val Loss: 0.9518 | Train Acc: 0.7238 | Val Acc: 0.7120
# Fold 1 completed in 217.02 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5195 | Val Loss: 3.4424 | Train Acc: 0.0573 | Val Acc: 0.0594
# Epoch 011 | Train Loss: 2.7849 | Val Loss: 2.4595 | Train Acc: 0.3319 | Val Acc: 0.3131
# Epoch 021 | Train Loss: 2.3093 | Val Loss: 1.9292 | Train Acc: 0.4464 | Val Acc: 0.4382
# Epoch 031 | Train Loss: 1.9965 | Val Loss: 1.6470 | Train Acc: 0.5225 | Val Acc: 0.5080
# Epoch 041 | Train Loss: 1.8100 | Val Loss: 1.4590 | Train Acc: 0.5810 | Val Acc: 0.5719
# Epoch 051 | Train Loss: 1.6681 | Val Loss: 1.3252 | Train Acc: 0.6092 | Val Acc: 0.6035
# Epoch 061 | Train Loss: 1.5443 | Val Loss: 1.2084 | Train Acc: 0.6504 | Val Acc: 0.6416
# Epoch 071 | Train Loss: 1.4550 | Val Loss: 1.1377 | Train Acc: 0.6598 | Val Acc: 0.6461
# Epoch 081 | Train Loss: 1.3700 | Val Loss: 1.0663 | Train Acc: 0.6780 | Val Acc: 0.6641
# Epoch 091 | Train Loss: 1.3213 | Val Loss: 1.0096 | Train Acc: 0.7026 | Val Acc: 0.6934
# Epoch 100 | Train Loss: 1.2601 | Val Loss: 0.9671 | Train Acc: 0.7117 | Val Acc: 0.6904
# Fold 2 completed in 219.56 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5177 | Val Loss: 3.4414 | Train Acc: 0.0631 | Val Acc: 0.0544
# Epoch 011 | Train Loss: 2.8004 | Val Loss: 2.4017 | Train Acc: 0.3297 | Val Acc: 0.3229
# Epoch 021 | Train Loss: 2.3038 | Val Loss: 1.8859 | Train Acc: 0.4457 | Val Acc: 0.4556
# Epoch 031 | Train Loss: 1.9925 | Val Loss: 1.6068 | Train Acc: 0.5251 | Val Acc: 0.5313
# Epoch 041 | Train Loss: 1.7928 | Val Loss: 1.4295 | Train Acc: 0.5778 | Val Acc: 0.5784
# Epoch 051 | Train Loss: 1.6494 | Val Loss: 1.3233 | Train Acc: 0.5996 | Val Acc: 0.5946
# Epoch 061 | Train Loss: 1.5237 | Val Loss: 1.2050 | Train Acc: 0.6424 | Val Acc: 0.6342
# Epoch 071 | Train Loss: 1.4433 | Val Loss: 1.1238 | Train Acc: 0.6618 | Val Acc: 0.6449
# Epoch 081 | Train Loss: 1.3482 | Val Loss: 1.0093 | Train Acc: 0.7014 | Val Acc: 0.6886
# Epoch 091 | Train Loss: 1.2917 | Val Loss: 0.9534 | Train Acc: 0.7195 | Val Acc: 0.7079
# Epoch 100 | Train Loss: 1.2224 | Val Loss: 0.9479 | Train Acc: 0.7166 | Val Acc: 0.6907
# Fold 3 completed in 218.77 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5185 | Val Loss: 3.4491 | Train Acc: 0.0603 | Val Acc: 0.0553
# Epoch 011 | Train Loss: 2.7902 | Val Loss: 2.4827 | Train Acc: 0.3302 | Val Acc: 0.3100
# Epoch 021 | Train Loss: 2.2772 | Val Loss: 1.9412 | Train Acc: 0.4637 | Val Acc: 0.4451
# Epoch 031 | Train Loss: 1.9898 | Val Loss: 1.6761 | Train Acc: 0.5383 | Val Acc: 0.5114
# Epoch 041 | Train Loss: 1.7871 | Val Loss: 1.4901 | Train Acc: 0.5842 | Val Acc: 0.5608
# Epoch 051 | Train Loss: 1.6497 | Val Loss: 1.3678 | Train Acc: 0.6179 | Val Acc: 0.5930
# Epoch 061 | Train Loss: 1.5448 | Val Loss: 1.2783 | Train Acc: 0.6361 | Val Acc: 0.6122
# Epoch 071 | Train Loss: 1.4324 | Val Loss: 1.1762 | Train Acc: 0.6642 | Val Acc: 0.6430
# Epoch 081 | Train Loss: 1.3693 | Val Loss: 1.1059 | Train Acc: 0.6761 | Val Acc: 0.6599
# Epoch 091 | Train Loss: 1.3019 | Val Loss: 1.0475 | Train Acc: 0.6971 | Val Acc: 0.6773
# Epoch 100 | Train Loss: 1.2512 | Val Loss: 0.9853 | Train Acc: 0.7137 | Val Acc: 0.6977
# Fold 4 completed in 224.92 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5171 | Val Loss: 3.4393 | Train Acc: 0.0611 | Val Acc: 0.0648
# Epoch 011 | Train Loss: 2.8036 | Val Loss: 2.4360 | Train Acc: 0.3262 | Val Acc: 0.3274
# Epoch 021 | Train Loss: 2.2943 | Val Loss: 1.9231 | Train Acc: 0.4484 | Val Acc: 0.4377
# Epoch 031 | Train Loss: 2.0069 | Val Loss: 1.6476 | Train Acc: 0.5342 | Val Acc: 0.5209
# Epoch 041 | Train Loss: 1.8115 | Val Loss: 1.4688 | Train Acc: 0.5600 | Val Acc: 0.5534
# Epoch 051 | Train Loss: 1.6508 | Val Loss: 1.3341 | Train Acc: 0.6088 | Val Acc: 0.5969
# Epoch 061 | Train Loss: 1.5522 | Val Loss: 1.2017 | Train Acc: 0.6407 | Val Acc: 0.6460
# Epoch 071 | Train Loss: 1.4523 | Val Loss: 1.1072 | Train Acc: 0.6622 | Val Acc: 0.6652
# Epoch 081 | Train Loss: 1.3931 | Val Loss: 1.0489 | Train Acc: 0.6817 | Val Acc: 0.6883
# Epoch 091 | Train Loss: 1.3072 | Val Loss: 0.9712 | Train Acc: 0.6996 | Val Acc: 0.6968
# Epoch 100 | Train Loss: 1.2640 | Val Loss: 0.9323 | Train Acc: 0.7098 | Val Acc: 0.7137
# Fold 5 completed in 226.73 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.7009
#
# Trial 2/16: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5257 | Val Loss: 3.5096 | Train Acc: 0.0312 | Val Acc: 0.0322
# Epoch 011 | Train Loss: 3.3961 | Val Loss: 3.3487 | Train Acc: 0.0848 | Val Acc: 0.0804
# Epoch 021 | Train Loss: 3.2496 | Val Loss: 3.1488 | Train Acc: 0.1394 | Val Acc: 0.1263
# Epoch 031 | Train Loss: 3.0943 | Val Loss: 2.9283 | Train Acc: 0.1898 | Val Acc: 0.1818
# Epoch 041 | Train Loss: 2.9472 | Val Loss: 2.7098 | Train Acc: 0.2523 | Val Acc: 0.2428
# Epoch 051 | Train Loss: 2.7873 | Val Loss: 2.5105 | Train Acc: 0.3097 | Val Acc: 0.2948
# Epoch 061 | Train Loss: 2.6659 | Val Loss: 2.3492 | Train Acc: 0.3557 | Val Acc: 0.3374
# Epoch 071 | Train Loss: 2.5496 | Val Loss: 2.2194 | Train Acc: 0.3874 | Val Acc: 0.3658
# Epoch 081 | Train Loss: 2.4567 | Val Loss: 2.1102 | Train Acc: 0.4091 | Val Acc: 0.3856
# Epoch 091 | Train Loss: 2.3524 | Val Loss: 2.0153 | Train Acc: 0.4343 | Val Acc: 0.4098
# Epoch 100 | Train Loss: 2.2764 | Val Loss: 1.9377 | Train Acc: 0.4462 | Val Acc: 0.4302
# Fold 1 completed in 259.20 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5258 | Val Loss: 3.5082 | Train Acc: 0.0302 | Val Acc: 0.0316
# Epoch 011 | Train Loss: 3.4053 | Val Loss: 3.3474 | Train Acc: 0.0831 | Val Acc: 0.0887
# Epoch 021 | Train Loss: 3.2564 | Val Loss: 3.1355 | Train Acc: 0.1428 | Val Acc: 0.1422
# Epoch 031 | Train Loss: 3.0907 | Val Loss: 2.9131 | Train Acc: 0.1910 | Val Acc: 0.1925
# Epoch 041 | Train Loss: 2.9296 | Val Loss: 2.6950 | Train Acc: 0.2655 | Val Acc: 0.2558
# Epoch 051 | Train Loss: 2.7791 | Val Loss: 2.5021 | Train Acc: 0.3218 | Val Acc: 0.3114
# Epoch 061 | Train Loss: 2.6506 | Val Loss: 2.3469 | Train Acc: 0.3543 | Val Acc: 0.3451
# Epoch 071 | Train Loss: 2.5282 | Val Loss: 2.2189 | Train Acc: 0.3904 | Val Acc: 0.3835
# Epoch 081 | Train Loss: 2.4305 | Val Loss: 2.1134 | Train Acc: 0.4174 | Val Acc: 0.4066
# Epoch 091 | Train Loss: 2.3500 | Val Loss: 2.0173 | Train Acc: 0.4365 | Val Acc: 0.4267
# Epoch 100 | Train Loss: 2.2557 | Val Loss: 1.9411 | Train Acc: 0.4512 | Val Acc: 0.4397
# Fold 2 completed in 257.45 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5233 | Val Loss: 3.5081 | Train Acc: 0.0318 | Val Acc: 0.0266
# Epoch 011 | Train Loss: 3.4063 | Val Loss: 3.3436 | Train Acc: 0.0845 | Val Acc: 0.0789
# Epoch 021 | Train Loss: 3.2607 | Val Loss: 3.1248 | Train Acc: 0.1335 | Val Acc: 0.1348
# Epoch 031 | Train Loss: 3.0971 | Val Loss: 2.8875 | Train Acc: 0.1931 | Val Acc: 0.1922
# Epoch 041 | Train Loss: 2.9294 | Val Loss: 2.6532 | Train Acc: 0.2630 | Val Acc: 0.2561
# Epoch 051 | Train Loss: 2.7879 | Val Loss: 2.4519 | Train Acc: 0.3155 | Val Acc: 0.3134
# Epoch 061 | Train Loss: 2.6558 | Val Loss: 2.2908 | Train Acc: 0.3553 | Val Acc: 0.3527
# Epoch 071 | Train Loss: 2.5532 | Val Loss: 2.1651 | Train Acc: 0.3856 | Val Acc: 0.3930
# Epoch 081 | Train Loss: 2.4352 | Val Loss: 2.0530 | Train Acc: 0.4148 | Val Acc: 0.4320
# Epoch 091 | Train Loss: 2.3485 | Val Loss: 1.9615 | Train Acc: 0.4362 | Val Acc: 0.4506
# Epoch 100 | Train Loss: 2.2704 | Val Loss: 1.8883 | Train Acc: 0.4555 | Val Acc: 0.4710
# Fold 3 completed in 255.84 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5242 | Val Loss: 3.5075 | Train Acc: 0.0301 | Val Acc: 0.0314
# Epoch 011 | Train Loss: 3.4038 | Val Loss: 3.3530 | Train Acc: 0.0832 | Val Acc: 0.0846
# Epoch 021 | Train Loss: 3.2521 | Val Loss: 3.1476 | Train Acc: 0.1381 | Val Acc: 0.1290
# Epoch 031 | Train Loss: 3.0904 | Val Loss: 2.9286 | Train Acc: 0.1927 | Val Acc: 0.1798
# Epoch 041 | Train Loss: 2.9320 | Val Loss: 2.7171 | Train Acc: 0.2605 | Val Acc: 0.2470
# Epoch 051 | Train Loss: 2.7808 | Val Loss: 2.5264 | Train Acc: 0.3177 | Val Acc: 0.3123
# Epoch 061 | Train Loss: 2.6486 | Val Loss: 2.3733 | Train Acc: 0.3553 | Val Acc: 0.3401
# Epoch 071 | Train Loss: 2.5272 | Val Loss: 2.2464 | Train Acc: 0.3903 | Val Acc: 0.3709
# Epoch 081 | Train Loss: 2.4335 | Val Loss: 2.1396 | Train Acc: 0.4131 | Val Acc: 0.3937
# Epoch 091 | Train Loss: 2.3411 | Val Loss: 2.0461 | Train Acc: 0.4318 | Val Acc: 0.4135
# Epoch 100 | Train Loss: 2.2679 | Val Loss: 1.9687 | Train Acc: 0.4526 | Val Acc: 0.4371
# Fold 4 completed in 254.05 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5230 | Val Loss: 3.5113 | Train Acc: 0.0302 | Val Acc: 0.0302
# Epoch 011 | Train Loss: 3.4050 | Val Loss: 3.3452 | Train Acc: 0.0829 | Val Acc: 0.0840
# Epoch 021 | Train Loss: 3.2588 | Val Loss: 3.1335 | Train Acc: 0.1404 | Val Acc: 0.1432
# Epoch 031 | Train Loss: 3.1001 | Val Loss: 2.9029 | Train Acc: 0.1906 | Val Acc: 0.1934
# Epoch 041 | Train Loss: 2.9386 | Val Loss: 2.6858 | Train Acc: 0.2480 | Val Acc: 0.2564
# Epoch 051 | Train Loss: 2.7845 | Val Loss: 2.4870 | Train Acc: 0.3061 | Val Acc: 0.3159
# Epoch 061 | Train Loss: 2.6515 | Val Loss: 2.3283 | Train Acc: 0.3503 | Val Acc: 0.3529
# Epoch 071 | Train Loss: 2.5373 | Val Loss: 2.2024 | Train Acc: 0.3885 | Val Acc: 0.3910
# Epoch 081 | Train Loss: 2.4430 | Val Loss: 2.0957 | Train Acc: 0.4124 | Val Acc: 0.4153
# Epoch 091 | Train Loss: 2.3577 | Val Loss: 2.0039 | Train Acc: 0.4327 | Val Acc: 0.4321
# Epoch 100 | Train Loss: 2.2682 | Val Loss: 1.9287 | Train Acc: 0.4545 | Val Acc: 0.4454
# Fold 5 completed in 251.58 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.4447
#
# Trial 3/16: {'learning_rate': 0.01, 'l2_lambda': 0.01, 'batch_size': 64, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5190 | Val Loss: 3.4426 | Train Acc: 0.0651 | Val Acc: 0.0642
# Epoch 011 | Train Loss: 2.8004 | Val Loss: 2.4789 | Train Acc: 0.3076 | Val Acc: 0.2939
# Epoch 021 | Train Loss: 2.2980 | Val Loss: 1.9369 | Train Acc: 0.4397 | Val Acc: 0.4299
# Epoch 031 | Train Loss: 1.9961 | Val Loss: 1.6413 | Train Acc: 0.5211 | Val Acc: 0.5171
# Epoch 041 | Train Loss: 1.7987 | Val Loss: 1.4620 | Train Acc: 0.5670 | Val Acc: 0.5789
# Epoch 051 | Train Loss: 1.6391 | Val Loss: 1.3633 | Train Acc: 0.5866 | Val Acc: 0.5837
# Epoch 061 | Train Loss: 1.5227 | Val Loss: 1.2123 | Train Acc: 0.6475 | Val Acc: 0.6372
# Epoch 071 | Train Loss: 1.4198 | Val Loss: 1.1280 | Train Acc: 0.6661 | Val Acc: 0.6659
# Epoch 081 | Train Loss: 1.3572 | Val Loss: 1.0459 | Train Acc: 0.6957 | Val Acc: 0.6863
# Epoch 091 | Train Loss: 1.2783 | Val Loss: 1.0014 | Train Acc: 0.7097 | Val Acc: 0.6957
# Epoch 100 | Train Loss: 1.2249 | Val Loss: 0.9518 | Train Acc: 0.7238 | Val Acc: 0.7120
# Fold 1 completed in 216.82 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5195 | Val Loss: 3.4424 | Train Acc: 0.0573 | Val Acc: 0.0594
# Epoch 011 | Train Loss: 2.7849 | Val Loss: 2.4595 | Train Acc: 0.3319 | Val Acc: 0.3131
# Epoch 021 | Train Loss: 2.3093 | Val Loss: 1.9292 | Train Acc: 0.4464 | Val Acc: 0.4382
# Epoch 031 | Train Loss: 1.9965 | Val Loss: 1.6470 | Train Acc: 0.5225 | Val Acc: 0.5080
# Epoch 041 | Train Loss: 1.8100 | Val Loss: 1.4590 | Train Acc: 0.5810 | Val Acc: 0.5719
# Epoch 051 | Train Loss: 1.6681 | Val Loss: 1.3252 | Train Acc: 0.6092 | Val Acc: 0.6035
# Epoch 061 | Train Loss: 1.5443 | Val Loss: 1.2084 | Train Acc: 0.6504 | Val Acc: 0.6416
# Epoch 071 | Train Loss: 1.4550 | Val Loss: 1.1377 | Train Acc: 0.6598 | Val Acc: 0.6461
# Epoch 081 | Train Loss: 1.3700 | Val Loss: 1.0663 | Train Acc: 0.6780 | Val Acc: 0.6641
# Epoch 091 | Train Loss: 1.3213 | Val Loss: 1.0096 | Train Acc: 0.7026 | Val Acc: 0.6934
# Epoch 100 | Train Loss: 1.2601 | Val Loss: 0.9671 | Train Acc: 0.7117 | Val Acc: 0.6904
# Fold 2 completed in 219.90 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5177 | Val Loss: 3.4414 | Train Acc: 0.0631 | Val Acc: 0.0544
# Epoch 011 | Train Loss: 2.8004 | Val Loss: 2.4017 | Train Acc: 0.3297 | Val Acc: 0.3229
# Epoch 021 | Train Loss: 2.3038 | Val Loss: 1.8859 | Train Acc: 0.4457 | Val Acc: 0.4556
# Epoch 031 | Train Loss: 1.9925 | Val Loss: 1.6068 | Train Acc: 0.5251 | Val Acc: 0.5313
# Epoch 041 | Train Loss: 1.7928 | Val Loss: 1.4295 | Train Acc: 0.5778 | Val Acc: 0.5784
# Epoch 051 | Train Loss: 1.6494 | Val Loss: 1.3233 | Train Acc: 0.5996 | Val Acc: 0.5946
# Epoch 061 | Train Loss: 1.5237 | Val Loss: 1.2050 | Train Acc: 0.6424 | Val Acc: 0.6342
# Epoch 071 | Train Loss: 1.4433 | Val Loss: 1.1238 | Train Acc: 0.6618 | Val Acc: 0.6449
# Epoch 081 | Train Loss: 1.3482 | Val Loss: 1.0093 | Train Acc: 0.7014 | Val Acc: 0.6886
# Epoch 091 | Train Loss: 1.2917 | Val Loss: 0.9534 | Train Acc: 0.7195 | Val Acc: 0.7079
# Epoch 100 | Train Loss: 1.2224 | Val Loss: 0.9479 | Train Acc: 0.7166 | Val Acc: 0.6907
# Fold 3 completed in 217.23 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5185 | Val Loss: 3.4491 | Train Acc: 0.0603 | Val Acc: 0.0553
# Epoch 011 | Train Loss: 2.7902 | Val Loss: 2.4827 | Train Acc: 0.3302 | Val Acc: 0.3100
# Epoch 021 | Train Loss: 2.2772 | Val Loss: 1.9412 | Train Acc: 0.4637 | Val Acc: 0.4451
# Epoch 031 | Train Loss: 1.9898 | Val Loss: 1.6761 | Train Acc: 0.5383 | Val Acc: 0.5114
# Epoch 041 | Train Loss: 1.7871 | Val Loss: 1.4901 | Train Acc: 0.5842 | Val Acc: 0.5608
# Epoch 051 | Train Loss: 1.6497 | Val Loss: 1.3678 | Train Acc: 0.6179 | Val Acc: 0.5930
# Epoch 061 | Train Loss: 1.5448 | Val Loss: 1.2783 | Train Acc: 0.6361 | Val Acc: 0.6122
# Epoch 071 | Train Loss: 1.4324 | Val Loss: 1.1762 | Train Acc: 0.6642 | Val Acc: 0.6430
# Epoch 081 | Train Loss: 1.3693 | Val Loss: 1.1059 | Train Acc: 0.6761 | Val Acc: 0.6599
# Epoch 091 | Train Loss: 1.3019 | Val Loss: 1.0475 | Train Acc: 0.6971 | Val Acc: 0.6773
# Epoch 100 | Train Loss: 1.2512 | Val Loss: 0.9853 | Train Acc: 0.7137 | Val Acc: 0.6977
# Fold 4 completed in 218.57 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5171 | Val Loss: 3.4393 | Train Acc: 0.0611 | Val Acc: 0.0648
# Epoch 011 | Train Loss: 2.8036 | Val Loss: 2.4360 | Train Acc: 0.3262 | Val Acc: 0.3274
# Epoch 021 | Train Loss: 2.2943 | Val Loss: 1.9231 | Train Acc: 0.4484 | Val Acc: 0.4377
# Epoch 031 | Train Loss: 2.0069 | Val Loss: 1.6476 | Train Acc: 0.5342 | Val Acc: 0.5209
# Epoch 041 | Train Loss: 1.8115 | Val Loss: 1.4688 | Train Acc: 0.5600 | Val Acc: 0.5534
# Epoch 051 | Train Loss: 1.6508 | Val Loss: 1.3341 | Train Acc: 0.6088 | Val Acc: 0.5969
# Epoch 061 | Train Loss: 1.5522 | Val Loss: 1.2017 | Train Acc: 0.6407 | Val Acc: 0.6460
# Epoch 071 | Train Loss: 1.4523 | Val Loss: 1.1072 | Train Acc: 0.6622 | Val Acc: 0.6652
# Epoch 081 | Train Loss: 1.3931 | Val Loss: 1.0489 | Train Acc: 0.6817 | Val Acc: 0.6883
# Epoch 091 | Train Loss: 1.3072 | Val Loss: 0.9712 | Train Acc: 0.6996 | Val Acc: 0.6968
# Epoch 100 | Train Loss: 1.2640 | Val Loss: 0.9323 | Train Acc: 0.7098 | Val Acc: 0.7137
# Fold 5 completed in 215.62 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.7009
#
# Trial 4/16: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 64, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5401 | Val Loss: 3.5285 | Train Acc: 0.0295 | Val Acc: 0.0284
# Epoch 011 | Train Loss: 3.4650 | Val Loss: 3.4346 | Train Acc: 0.0666 | Val Acc: 0.0621
# Epoch 021 | Train Loss: 3.4063 | Val Loss: 3.3586 | Train Acc: 0.0826 | Val Acc: 0.0733
# Epoch 031 | Train Loss: 3.3393 | Val Loss: 3.2647 | Train Acc: 0.1107 | Val Acc: 0.1002
# Epoch 041 | Train Loss: 3.2664 | Val Loss: 3.1604 | Train Acc: 0.1354 | Val Acc: 0.1230
# Epoch 051 | Train Loss: 3.1828 | Val Loss: 3.0502 | Train Acc: 0.1591 | Val Acc: 0.1535
# Epoch 061 | Train Loss: 3.1056 | Val Loss: 2.9390 | Train Acc: 0.1857 | Val Acc: 0.1801
# Epoch 071 | Train Loss: 3.0219 | Val Loss: 2.8276 | Train Acc: 0.2158 | Val Acc: 0.2111
# Epoch 081 | Train Loss: 2.9452 | Val Loss: 2.7162 | Train Acc: 0.2488 | Val Acc: 0.2422
# Epoch 091 | Train Loss: 2.8585 | Val Loss: 2.6093 | Train Acc: 0.2823 | Val Acc: 0.2705
# Epoch 100 | Train Loss: 2.7898 | Val Loss: 2.5226 | Train Acc: 0.3053 | Val Acc: 0.2924
# Fold 1 completed in 217.99 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5409 | Val Loss: 3.5255 | Train Acc: 0.0279 | Val Acc: 0.0296
# Epoch 011 | Train Loss: 3.4696 | Val Loss: 3.4347 | Train Acc: 0.0639 | Val Acc: 0.0662
# Epoch 021 | Train Loss: 3.4138 | Val Loss: 3.3544 | Train Acc: 0.0824 | Val Acc: 0.0846
# Epoch 031 | Train Loss: 3.3426 | Val Loss: 3.2553 | Train Acc: 0.1125 | Val Acc: 0.1186
# Epoch 041 | Train Loss: 3.2661 | Val Loss: 3.1447 | Train Acc: 0.1385 | Val Acc: 0.1413
# Epoch 051 | Train Loss: 3.1854 | Val Loss: 3.0323 | Train Acc: 0.1632 | Val Acc: 0.1614
# Epoch 061 | Train Loss: 3.1016 | Val Loss: 2.9214 | Train Acc: 0.1884 | Val Acc: 0.1872
# Epoch 071 | Train Loss: 3.0104 | Val Loss: 2.8094 | Train Acc: 0.2224 | Val Acc: 0.2141
# Epoch 081 | Train Loss: 2.9284 | Val Loss: 2.7009 | Train Acc: 0.2628 | Val Acc: 0.2564
# Epoch 091 | Train Loss: 2.8504 | Val Loss: 2.5986 | Train Acc: 0.2925 | Val Acc: 0.2821
# Epoch 100 | Train Loss: 2.7716 | Val Loss: 2.5107 | Train Acc: 0.3170 | Val Acc: 0.3060
# Fold 2 completed in 217.37 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5378 | Val Loss: 3.5253 | Train Acc: 0.0301 | Val Acc: 0.0240
# Epoch 011 | Train Loss: 3.4691 | Val Loss: 3.4336 | Train Acc: 0.0665 | Val Acc: 0.0618
# Epoch 021 | Train Loss: 3.4127 | Val Loss: 3.3525 | Train Acc: 0.0852 | Val Acc: 0.0772
# Epoch 031 | Train Loss: 3.3473 | Val Loss: 3.2499 | Train Acc: 0.1041 | Val Acc: 0.1026
# Epoch 041 | Train Loss: 3.2678 | Val Loss: 3.1318 | Train Acc: 0.1327 | Val Acc: 0.1351
# Epoch 051 | Train Loss: 3.1895 | Val Loss: 3.0121 | Train Acc: 0.1598 | Val Acc: 0.1614
# Epoch 061 | Train Loss: 3.1068 | Val Loss: 2.8929 | Train Acc: 0.1898 | Val Acc: 0.1910
# Epoch 071 | Train Loss: 3.0260 | Val Loss: 2.7758 | Train Acc: 0.2265 | Val Acc: 0.2224
# Epoch 081 | Train Loss: 2.9293 | Val Loss: 2.6571 | Train Acc: 0.2611 | Val Acc: 0.2567
# Epoch 091 | Train Loss: 2.8555 | Val Loss: 2.5481 | Train Acc: 0.2911 | Val Acc: 0.2889
# Epoch 100 | Train Loss: 2.7888 | Val Loss: 2.4613 | Train Acc: 0.3155 | Val Acc: 0.3102
# Fold 3 completed in 216.44 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5390 | Val Loss: 3.5231 | Train Acc: 0.0286 | Val Acc: 0.0308
# Epoch 011 | Train Loss: 3.4693 | Val Loss: 3.4376 | Train Acc: 0.0660 | Val Acc: 0.0621
# Epoch 021 | Train Loss: 3.4089 | Val Loss: 3.3603 | Train Acc: 0.0835 | Val Acc: 0.0810
# Epoch 031 | Train Loss: 3.3412 | Val Loss: 3.2642 | Train Acc: 0.1112 | Val Acc: 0.1068
# Epoch 041 | Train Loss: 3.2669 | Val Loss: 3.1573 | Train Acc: 0.1383 | Val Acc: 0.1293
# Epoch 051 | Train Loss: 3.1866 | Val Loss: 3.0465 | Train Acc: 0.1623 | Val Acc: 0.1503
# Epoch 061 | Train Loss: 3.0997 | Val Loss: 2.9364 | Train Acc: 0.1910 | Val Acc: 0.1760
# Epoch 071 | Train Loss: 3.0122 | Val Loss: 2.8278 | Train Acc: 0.2246 | Val Acc: 0.2153
# Epoch 081 | Train Loss: 2.9345 | Val Loss: 2.7215 | Train Acc: 0.2582 | Val Acc: 0.2458
# Epoch 091 | Train Loss: 2.8495 | Val Loss: 2.6192 | Train Acc: 0.2886 | Val Acc: 0.2748
# Epoch 100 | Train Loss: 2.7828 | Val Loss: 2.5328 | Train Acc: 0.3129 | Val Acc: 0.3032
# Fold 4 completed in 219.58 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5374 | Val Loss: 3.5298 | Train Acc: 0.0280 | Val Acc: 0.0299
# Epoch 011 | Train Loss: 3.4687 | Val Loss: 3.4325 | Train Acc: 0.0620 | Val Acc: 0.0671
# Epoch 021 | Train Loss: 3.4120 | Val Loss: 3.3526 | Train Acc: 0.0809 | Val Acc: 0.0858
# Epoch 031 | Train Loss: 3.3436 | Val Loss: 3.2527 | Train Acc: 0.1095 | Val Acc: 0.1026
# Epoch 041 | Train Loss: 3.2696 | Val Loss: 3.1410 | Train Acc: 0.1378 | Val Acc: 0.1440
# Epoch 051 | Train Loss: 3.1883 | Val Loss: 3.0245 | Train Acc: 0.1627 | Val Acc: 0.1686
# Epoch 061 | Train Loss: 3.1058 | Val Loss: 2.9095 | Train Acc: 0.1888 | Val Acc: 0.1884
# Epoch 071 | Train Loss: 3.0248 | Val Loss: 2.7974 | Train Acc: 0.2167 | Val Acc: 0.2221
# Epoch 081 | Train Loss: 2.9451 | Val Loss: 2.6871 | Train Acc: 0.2520 | Val Acc: 0.2555
# Epoch 091 | Train Loss: 2.8715 | Val Loss: 2.5815 | Train Acc: 0.2834 | Val Acc: 0.2899
# Epoch 100 | Train Loss: 2.7886 | Val Loss: 2.4952 | Train Acc: 0.3069 | Val Acc: 0.3135
# Fold 5 completed in 221.86 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.3051
#
# Trial 5/16: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'adam'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 2.9324 | Val Loss: 2.1683 | Train Acc: 0.4083 | Val Acc: 0.3823
# Epoch 011 | Train Loss: 1.2396 | Val Loss: 0.9687 | Train Acc: 0.7133 | Val Acc: 0.6892
# Epoch 021 | Train Loss: 1.0223 | Val Loss: 0.7761 | Train Acc: 0.7730 | Val Acc: 0.7507
# Epoch 031 | Train Loss: 0.9056 | Val Loss: 0.6797 | Train Acc: 0.7921 | Val Acc: 0.7830
# Epoch 041 | Train Loss: 0.8357 | Val Loss: 0.6975 | Train Acc: 0.7978 | Val Acc: 0.7803
# Epoch 051 | Train Loss: 0.7965 | Val Loss: 0.6312 | Train Acc: 0.8091 | Val Acc: 0.7921
# Epoch 061 | Train Loss: 0.7593 | Val Loss: 0.5799 | Train Acc: 0.8297 | Val Acc: 0.8176
# Epoch 071 | Train Loss: 0.7182 | Val Loss: 0.5568 | Train Acc: 0.8399 | Val Acc: 0.8220
# Epoch 081 | Train Loss: 0.7215 | Val Loss: 0.5429 | Train Acc: 0.8469 | Val Acc: 0.8205
# Epoch 091 | Train Loss: 0.6807 | Val Loss: 0.5071 | Train Acc: 0.8527 | Val Acc: 0.8412
# Epoch 100 | Train Loss: 0.6713 | Val Loss: 0.5493 | Train Acc: 0.8436 | Val Acc: 0.8270
# Fold 1 completed in 331.87 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 2.9267 | Val Loss: 2.1257 | Train Acc: 0.4004 | Val Acc: 0.3956
# Epoch 011 | Train Loss: 1.1903 | Val Loss: 0.9384 | Train Acc: 0.7129 | Val Acc: 0.6943
# Epoch 021 | Train Loss: 0.9954 | Val Loss: 0.7590 | Train Acc: 0.7662 | Val Acc: 0.7555
# Epoch 031 | Train Loss: 0.8903 | Val Loss: 0.7151 | Train Acc: 0.7768 | Val Acc: 0.7596
# Epoch 041 | Train Loss: 0.8306 | Val Loss: 0.6122 | Train Acc: 0.8118 | Val Acc: 0.7927
# Epoch 051 | Train Loss: 0.7866 | Val Loss: 0.5660 | Train Acc: 0.8360 | Val Acc: 0.8187
# Epoch 061 | Train Loss: 0.7362 | Val Loss: 0.5694 | Train Acc: 0.8288 | Val Acc: 0.8031
# Epoch 071 | Train Loss: 0.7166 | Val Loss: 0.5286 | Train Acc: 0.8395 | Val Acc: 0.8190
# Epoch 081 | Train Loss: 0.6946 | Val Loss: 0.5206 | Train Acc: 0.8412 | Val Acc: 0.8179
# Epoch 091 | Train Loss: 0.6671 | Val Loss: 0.4886 | Train Acc: 0.8549 | Val Acc: 0.8318
# Epoch 100 | Train Loss: 0.6510 | Val Loss: 0.4629 | Train Acc: 0.8594 | Val Acc: 0.8386
# Fold 2 completed in 330.01 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 2.9282 | Val Loss: 2.0986 | Train Acc: 0.3705 | Val Acc: 0.3841
# Epoch 011 | Train Loss: 1.2311 | Val Loss: 0.9385 | Train Acc: 0.7097 | Val Acc: 0.7020
# Epoch 021 | Train Loss: 1.0065 | Val Loss: 0.8164 | Train Acc: 0.7441 | Val Acc: 0.7333
# Epoch 031 | Train Loss: 0.8997 | Val Loss: 0.6764 | Train Acc: 0.7909 | Val Acc: 0.7818
# Epoch 041 | Train Loss: 0.8312 | Val Loss: 0.6180 | Train Acc: 0.8076 | Val Acc: 0.7986
# Epoch 051 | Train Loss: 0.7744 | Val Loss: 0.5742 | Train Acc: 0.8169 | Val Acc: 0.8060
# Epoch 061 | Train Loss: 0.7402 | Val Loss: 0.5434 | Train Acc: 0.8305 | Val Acc: 0.8143
# Epoch 071 | Train Loss: 0.7225 | Val Loss: 0.5031 | Train Acc: 0.8416 | Val Acc: 0.8374
# Epoch 081 | Train Loss: 0.6900 | Val Loss: 0.4844 | Train Acc: 0.8464 | Val Acc: 0.8350
# Early stopping at epoch 89
# Fold 3 completed in 309.73 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 2.9415 | Val Loss: 2.1825 | Train Acc: 0.3726 | Val Acc: 0.3537
# Epoch 011 | Train Loss: 1.1813 | Val Loss: 0.9359 | Train Acc: 0.7107 | Val Acc: 0.6980
# Epoch 021 | Train Loss: 0.9636 | Val Loss: 0.7504 | Train Acc: 0.7745 | Val Acc: 0.7613
# Epoch 031 | Train Loss: 0.8630 | Val Loss: 0.6581 | Train Acc: 0.8028 | Val Acc: 0.7903
# Epoch 041 | Train Loss: 0.7927 | Val Loss: 0.5920 | Train Acc: 0.8271 | Val Acc: 0.8004
# Epoch 051 | Train Loss: 0.7560 | Val Loss: 0.5720 | Train Acc: 0.8238 | Val Acc: 0.8140
# Epoch 061 | Train Loss: 0.7154 | Val Loss: 0.5683 | Train Acc: 0.8230 | Val Acc: 0.8092
# Early stopping at epoch 68
# Fold 4 completed in 214.96 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 2.9295 | Val Loss: 2.2140 | Train Acc: 0.3526 | Val Acc: 0.3570
# Epoch 011 | Train Loss: 1.2329 | Val Loss: 0.9833 | Train Acc: 0.6958 | Val Acc: 0.6859
# Epoch 021 | Train Loss: 1.0240 | Val Loss: 0.7980 | Train Acc: 0.7429 | Val Acc: 0.7433
# Epoch 031 | Train Loss: 0.9251 | Val Loss: 0.6810 | Train Acc: 0.7785 | Val Acc: 0.7835
# Epoch 041 | Train Loss: 0.8562 | Val Loss: 0.6102 | Train Acc: 0.8065 | Val Acc: 0.7989
# Epoch 051 | Train Loss: 0.8066 | Val Loss: 0.5893 | Train Acc: 0.8161 | Val Acc: 0.8131
# Epoch 061 | Train Loss: 0.7638 | Val Loss: 0.5394 | Train Acc: 0.8205 | Val Acc: 0.8187
# Epoch 071 | Train Loss: 0.7354 | Val Loss: 0.5301 | Train Acc: 0.8314 | Val Acc: 0.8211
# Epoch 081 | Train Loss: 0.7175 | Val Loss: 0.4967 | Train Acc: 0.8411 | Val Acc: 0.8308
# Epoch 091 | Train Loss: 0.6694 | Val Loss: 0.4673 | Train Acc: 0.8545 | Val Acc: 0.8441
# Epoch 100 | Train Loss: 0.6640 | Val Loss: 0.5061 | Train Acc: 0.8365 | Val Acc: 0.8323
# Fold 5 completed in 333.34 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.8293
#
# Trial 6/16: {'learning_rate': 0.01, 'l2_lambda': 0.001, 'batch_size': 64, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5012 | Val Loss: 3.4422 | Train Acc: 0.0657 | Val Acc: 0.0642
# Epoch 011 | Train Loss: 2.7787 | Val Loss: 2.4746 | Train Acc: 0.3096 | Val Acc: 0.2983
# Epoch 021 | Train Loss: 2.2720 | Val Loss: 1.9344 | Train Acc: 0.4394 | Val Acc: 0.4317
# Epoch 031 | Train Loss: 1.9671 | Val Loss: 1.6359 | Train Acc: 0.5228 | Val Acc: 0.5169
# Epoch 041 | Train Loss: 1.7671 | Val Loss: 1.4563 | Train Acc: 0.5691 | Val Acc: 0.5810
# Epoch 051 | Train Loss: 1.6056 | Val Loss: 1.3608 | Train Acc: 0.5870 | Val Acc: 0.5843
# Epoch 061 | Train Loss: 1.4869 | Val Loss: 1.2053 | Train Acc: 0.6480 | Val Acc: 0.6413
# Epoch 071 | Train Loss: 1.3819 | Val Loss: 1.1194 | Train Acc: 0.6662 | Val Acc: 0.6656
# Epoch 081 | Train Loss: 1.3178 | Val Loss: 1.0393 | Train Acc: 0.6970 | Val Acc: 0.6875
# Epoch 091 | Train Loss: 1.2371 | Val Loss: 0.9963 | Train Acc: 0.7119 | Val Acc: 0.6954
# Epoch 100 | Train Loss: 1.1823 | Val Loss: 0.9491 | Train Acc: 0.7241 | Val Acc: 0.7099
# Fold 1 completed in 217.41 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5017 | Val Loss: 3.4417 | Train Acc: 0.0583 | Val Acc: 0.0594
# Epoch 011 | Train Loss: 2.7642 | Val Loss: 2.4571 | Train Acc: 0.3307 | Val Acc: 0.3152
# Epoch 021 | Train Loss: 2.2844 | Val Loss: 1.9246 | Train Acc: 0.4471 | Val Acc: 0.4394
# Epoch 031 | Train Loss: 1.9683 | Val Loss: 1.6425 | Train Acc: 0.5221 | Val Acc: 0.5062
# Epoch 041 | Train Loss: 1.7781 | Val Loss: 1.4542 | Train Acc: 0.5824 | Val Acc: 0.5778
# Epoch 051 | Train Loss: 1.6335 | Val Loss: 1.3198 | Train Acc: 0.6116 | Val Acc: 0.6044
# Epoch 061 | Train Loss: 1.5080 | Val Loss: 1.2041 | Train Acc: 0.6480 | Val Acc: 0.6384
# Epoch 071 | Train Loss: 1.4161 | Val Loss: 1.1326 | Train Acc: 0.6596 | Val Acc: 0.6434
# Epoch 081 | Train Loss: 1.3293 | Val Loss: 1.0604 | Train Acc: 0.6803 | Val Acc: 0.6656
# Epoch 091 | Train Loss: 1.2789 | Val Loss: 1.0057 | Train Acc: 0.7021 | Val Acc: 0.6898
# Epoch 100 | Train Loss: 1.2135 | Val Loss: 0.9574 | Train Acc: 0.7111 | Val Acc: 0.6940
# Fold 2 completed in 215.70 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5000 | Val Loss: 3.4412 | Train Acc: 0.0628 | Val Acc: 0.0541
# Epoch 011 | Train Loss: 2.7805 | Val Loss: 2.3987 | Train Acc: 0.3294 | Val Acc: 0.3258
# Epoch 021 | Train Loss: 2.2771 | Val Loss: 1.8802 | Train Acc: 0.4488 | Val Acc: 0.4583
# Epoch 031 | Train Loss: 1.9639 | Val Loss: 1.6015 | Train Acc: 0.5276 | Val Acc: 0.5325
# Epoch 041 | Train Loss: 1.7615 | Val Loss: 1.4233 | Train Acc: 0.5786 | Val Acc: 0.5819
# Epoch 051 | Train Loss: 1.6168 | Val Loss: 1.3203 | Train Acc: 0.5992 | Val Acc: 0.5911
# Epoch 061 | Train Loss: 1.4883 | Val Loss: 1.1997 | Train Acc: 0.6431 | Val Acc: 0.6328
# Epoch 071 | Train Loss: 1.4056 | Val Loss: 1.1164 | Train Acc: 0.6612 | Val Acc: 0.6473
# Epoch 081 | Train Loss: 1.3073 | Val Loss: 1.0028 | Train Acc: 0.7007 | Val Acc: 0.6910
# Epoch 091 | Train Loss: 1.2508 | Val Loss: 0.9480 | Train Acc: 0.7214 | Val Acc: 0.7117
# Epoch 100 | Train Loss: 1.1795 | Val Loss: 0.9478 | Train Acc: 0.7155 | Val Acc: 0.6886
# Fold 3 completed in 215.94 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5008 | Val Loss: 3.4487 | Train Acc: 0.0604 | Val Acc: 0.0559
# Epoch 011 | Train Loss: 2.7710 | Val Loss: 2.4826 | Train Acc: 0.3295 | Val Acc: 0.3120
# Epoch 021 | Train Loss: 2.2545 | Val Loss: 1.9392 | Train Acc: 0.4634 | Val Acc: 0.4469
# Epoch 031 | Train Loss: 1.9637 | Val Loss: 1.6736 | Train Acc: 0.5371 | Val Acc: 0.5126
# Epoch 041 | Train Loss: 1.7582 | Val Loss: 1.4874 | Train Acc: 0.5842 | Val Acc: 0.5611
# Epoch 051 | Train Loss: 1.6178 | Val Loss: 1.3643 | Train Acc: 0.6191 | Val Acc: 0.5936
# Epoch 061 | Train Loss: 1.5105 | Val Loss: 1.2746 | Train Acc: 0.6356 | Val Acc: 0.6152
# Epoch 071 | Train Loss: 1.3956 | Val Loss: 1.1723 | Train Acc: 0.6646 | Val Acc: 0.6436
# Epoch 081 | Train Loss: 1.3308 | Val Loss: 1.1019 | Train Acc: 0.6777 | Val Acc: 0.6596
# Epoch 091 | Train Loss: 1.2633 | Val Loss: 1.0434 | Train Acc: 0.6966 | Val Acc: 0.6773
# Epoch 100 | Train Loss: 1.2096 | Val Loss: 0.9826 | Train Acc: 0.7152 | Val Acc: 0.6974
# Fold 4 completed in 215.82 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.4995 | Val Loss: 3.4388 | Train Acc: 0.0605 | Val Acc: 0.0657
# Epoch 011 | Train Loss: 2.7837 | Val Loss: 2.4344 | Train Acc: 0.3259 | Val Acc: 0.3265
# Epoch 021 | Train Loss: 2.2722 | Val Loss: 1.9227 | Train Acc: 0.4503 | Val Acc: 0.4383
# Epoch 031 | Train Loss: 1.9820 | Val Loss: 1.6458 | Train Acc: 0.5317 | Val Acc: 0.5200
# Epoch 041 | Train Loss: 1.7844 | Val Loss: 1.4680 | Train Acc: 0.5599 | Val Acc: 0.5507
# Epoch 051 | Train Loss: 1.6225 | Val Loss: 1.3311 | Train Acc: 0.6079 | Val Acc: 0.5983
# Epoch 061 | Train Loss: 1.5199 | Val Loss: 1.1964 | Train Acc: 0.6403 | Val Acc: 0.6513
# Epoch 071 | Train Loss: 1.4185 | Val Loss: 1.1033 | Train Acc: 0.6628 | Val Acc: 0.6634
# Epoch 081 | Train Loss: 1.3572 | Val Loss: 1.0469 | Train Acc: 0.6815 | Val Acc: 0.6874
# Epoch 091 | Train Loss: 1.2689 | Val Loss: 0.9662 | Train Acc: 0.6999 | Val Acc: 0.6945
# Epoch 100 | Train Loss: 1.2234 | Val Loss: 0.9289 | Train Acc: 0.7131 | Val Acc: 0.7164
# Fold 5 completed in 214.54 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.7013
#
# Trial 7/16: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'adam'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 2.9324 | Val Loss: 2.1683 | Train Acc: 0.4083 | Val Acc: 0.3823
# Epoch 011 | Train Loss: 1.2396 | Val Loss: 0.9687 | Train Acc: 0.7133 | Val Acc: 0.6892
# Epoch 021 | Train Loss: 1.0223 | Val Loss: 0.7761 | Train Acc: 0.7730 | Val Acc: 0.7507
# Epoch 031 | Train Loss: 0.9056 | Val Loss: 0.6797 | Train Acc: 0.7921 | Val Acc: 0.7830
# Epoch 041 | Train Loss: 0.8357 | Val Loss: 0.6975 | Train Acc: 0.7978 | Val Acc: 0.7803
# Epoch 051 | Train Loss: 0.7965 | Val Loss: 0.6312 | Train Acc: 0.8091 | Val Acc: 0.7921
# Epoch 061 | Train Loss: 0.7593 | Val Loss: 0.5799 | Train Acc: 0.8297 | Val Acc: 0.8176
# Epoch 071 | Train Loss: 0.7182 | Val Loss: 0.5568 | Train Acc: 0.8399 | Val Acc: 0.8220
# Epoch 081 | Train Loss: 0.7215 | Val Loss: 0.5429 | Train Acc: 0.8469 | Val Acc: 0.8205
# Epoch 091 | Train Loss: 0.6807 | Val Loss: 0.5071 | Train Acc: 0.8527 | Val Acc: 0.8412
# Epoch 100 | Train Loss: 0.6713 | Val Loss: 0.5493 | Train Acc: 0.8436 | Val Acc: 0.8270
# Fold 1 completed in 336.52 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 2.9267 | Val Loss: 2.1257 | Train Acc: 0.4004 | Val Acc: 0.3956
# Epoch 011 | Train Loss: 1.1903 | Val Loss: 0.9384 | Train Acc: 0.7129 | Val Acc: 0.6943
# Epoch 021 | Train Loss: 0.9954 | Val Loss: 0.7590 | Train Acc: 0.7662 | Val Acc: 0.7555
# Epoch 031 | Train Loss: 0.8903 | Val Loss: 0.7151 | Train Acc: 0.7768 | Val Acc: 0.7596
# Epoch 041 | Train Loss: 0.8306 | Val Loss: 0.6122 | Train Acc: 0.8118 | Val Acc: 0.7927
# Epoch 051 | Train Loss: 0.7866 | Val Loss: 0.5660 | Train Acc: 0.8360 | Val Acc: 0.8187
# Epoch 061 | Train Loss: 0.7362 | Val Loss: 0.5694 | Train Acc: 0.8288 | Val Acc: 0.8031
# Epoch 071 | Train Loss: 0.7166 | Val Loss: 0.5286 | Train Acc: 0.8395 | Val Acc: 0.8190
# Epoch 081 | Train Loss: 0.6946 | Val Loss: 0.5206 | Train Acc: 0.8412 | Val Acc: 0.8179
# Epoch 091 | Train Loss: 0.6671 | Val Loss: 0.4886 | Train Acc: 0.8549 | Val Acc: 0.8318
# Epoch 100 | Train Loss: 0.6510 | Val Loss: 0.4629 | Train Acc: 0.8594 | Val Acc: 0.8386
# Fold 2 completed in 324.12 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 2.9282 | Val Loss: 2.0986 | Train Acc: 0.3705 | Val Acc: 0.3841
# Epoch 011 | Train Loss: 1.2311 | Val Loss: 0.9385 | Train Acc: 0.7097 | Val Acc: 0.7020
# Epoch 021 | Train Loss: 1.0065 | Val Loss: 0.8164 | Train Acc: 0.7441 | Val Acc: 0.7333
# Epoch 031 | Train Loss: 0.8997 | Val Loss: 0.6764 | Train Acc: 0.7909 | Val Acc: 0.7818
# Epoch 041 | Train Loss: 0.8312 | Val Loss: 0.6180 | Train Acc: 0.8076 | Val Acc: 0.7986
# Epoch 051 | Train Loss: 0.7744 | Val Loss: 0.5742 | Train Acc: 0.8169 | Val Acc: 0.8060
# Epoch 061 | Train Loss: 0.7402 | Val Loss: 0.5434 | Train Acc: 0.8305 | Val Acc: 0.8143
# Epoch 071 | Train Loss: 0.7225 | Val Loss: 0.5031 | Train Acc: 0.8416 | Val Acc: 0.8374
# Epoch 081 | Train Loss: 0.6900 | Val Loss: 0.4844 | Train Acc: 0.8464 | Val Acc: 0.8350
# Early stopping at epoch 89
# Fold 3 completed in 308.15 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 2.9415 | Val Loss: 2.1825 | Train Acc: 0.3726 | Val Acc: 0.3537
# Epoch 011 | Train Loss: 1.1813 | Val Loss: 0.9359 | Train Acc: 0.7107 | Val Acc: 0.6980
# Epoch 021 | Train Loss: 0.9636 | Val Loss: 0.7504 | Train Acc: 0.7745 | Val Acc: 0.7613
# Epoch 031 | Train Loss: 0.8630 | Val Loss: 0.6581 | Train Acc: 0.8028 | Val Acc: 0.7903
# Epoch 041 | Train Loss: 0.7927 | Val Loss: 0.5920 | Train Acc: 0.8271 | Val Acc: 0.8004
# Epoch 051 | Train Loss: 0.7560 | Val Loss: 0.5720 | Train Acc: 0.8238 | Val Acc: 0.8140
# Epoch 061 | Train Loss: 0.7154 | Val Loss: 0.5683 | Train Acc: 0.8230 | Val Acc: 0.8092
# Early stopping at epoch 68
# Fold 4 completed in 213.35 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 2.9295 | Val Loss: 2.2140 | Train Acc: 0.3526 | Val Acc: 0.3570
# Epoch 011 | Train Loss: 1.2329 | Val Loss: 0.9833 | Train Acc: 0.6958 | Val Acc: 0.6859
# Epoch 021 | Train Loss: 1.0240 | Val Loss: 0.7980 | Train Acc: 0.7429 | Val Acc: 0.7433
# Epoch 031 | Train Loss: 0.9251 | Val Loss: 0.6810 | Train Acc: 0.7785 | Val Acc: 0.7835
# Epoch 041 | Train Loss: 0.8562 | Val Loss: 0.6102 | Train Acc: 0.8065 | Val Acc: 0.7989
# Epoch 051 | Train Loss: 0.8066 | Val Loss: 0.5893 | Train Acc: 0.8161 | Val Acc: 0.8131
# Epoch 061 | Train Loss: 0.7638 | Val Loss: 0.5394 | Train Acc: 0.8205 | Val Acc: 0.8187
# Epoch 071 | Train Loss: 0.7354 | Val Loss: 0.5301 | Train Acc: 0.8314 | Val Acc: 0.8211
# Epoch 081 | Train Loss: 0.7175 | Val Loss: 0.4967 | Train Acc: 0.8411 | Val Acc: 0.8308
# Epoch 091 | Train Loss: 0.6694 | Val Loss: 0.4673 | Train Acc: 0.8545 | Val Acc: 0.8441
# Epoch 100 | Train Loss: 0.6640 | Val Loss: 0.5061 | Train Acc: 0.8365 | Val Acc: 0.8323
# Fold 5 completed in 324.28 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.8293
#
# Trial 8/16: {'learning_rate': 0.01, 'l2_lambda': 0.01, 'batch_size': 64, 'optimizer': 'adam'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 2.7359 | Val Loss: 1.9781 | Train Acc: 0.3896 | Val Acc: 0.3823
# Epoch 011 | Train Loss: 1.6377 | Val Loss: 1.1409 | Train Acc: 0.6230 | Val Acc: 0.6183
# Epoch 021 | Train Loss: 1.5026 | Val Loss: 1.0710 | Train Acc: 0.6556 | Val Acc: 0.6493
# Epoch 031 | Train Loss: 1.4375 | Val Loss: 1.0664 | Train Acc: 0.6635 | Val Acc: 0.6532
# Epoch 041 | Train Loss: 1.3917 | Val Loss: 0.9772 | Train Acc: 0.6776 | Val Acc: 0.6659
# Epoch 051 | Train Loss: 1.3801 | Val Loss: 1.0226 | Train Acc: 0.6939 | Val Acc: 0.6750
# Early stopping at epoch 52
# Fold 1 completed in 124.93 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 2.7227 | Val Loss: 1.9287 | Train Acc: 0.4083 | Val Acc: 0.4051
# Epoch 011 | Train Loss: 1.6600 | Val Loss: 1.2245 | Train Acc: 0.6096 | Val Acc: 0.5905
# Epoch 021 | Train Loss: 1.5523 | Val Loss: 1.0794 | Train Acc: 0.6496 | Val Acc: 0.6390
# Epoch 031 | Train Loss: 1.4733 | Val Loss: 1.0477 | Train Acc: 0.6618 | Val Acc: 0.6484
# Epoch 041 | Train Loss: 1.4462 | Val Loss: 1.1329 | Train Acc: 0.6488 | Val Acc: 0.6277
# Early stopping at epoch 46
# Fold 2 completed in 113.65 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 2.6544 | Val Loss: 1.7293 | Train Acc: 0.4457 | Val Acc: 0.4358
# Epoch 011 | Train Loss: 1.5360 | Val Loss: 1.1573 | Train Acc: 0.6209 | Val Acc: 0.6283
# Epoch 021 | Train Loss: 1.4256 | Val Loss: 0.9946 | Train Acc: 0.6851 | Val Acc: 0.6789
# Epoch 031 | Train Loss: 1.3829 | Val Loss: 0.9114 | Train Acc: 0.6969 | Val Acc: 0.6963
# Epoch 041 | Train Loss: 1.3424 | Val Loss: 0.8411 | Train Acc: 0.7333 | Val Acc: 0.7247
# Early stopping at epoch 44
# Fold 3 completed in 104.79 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 2.7262 | Val Loss: 1.8641 | Train Acc: 0.4028 | Val Acc: 0.3957
# Epoch 011 | Train Loss: 1.5832 | Val Loss: 1.2155 | Train Acc: 0.6163 | Val Acc: 0.6019
# Epoch 021 | Train Loss: 1.4829 | Val Loss: 1.0658 | Train Acc: 0.6705 | Val Acc: 0.6628
# Epoch 031 | Train Loss: 1.4088 | Val Loss: 0.9445 | Train Acc: 0.6976 | Val Acc: 0.6930
# Epoch 041 | Train Loss: 1.3629 | Val Loss: 0.9277 | Train Acc: 0.7084 | Val Acc: 0.6924
# Epoch 051 | Train Loss: 1.3595 | Val Loss: 1.0037 | Train Acc: 0.6926 | Val Acc: 0.6749
# Early stopping at epoch 55
# Fold 4 completed in 133.38 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 2.7330 | Val Loss: 1.8498 | Train Acc: 0.4039 | Val Acc: 0.4061
# Epoch 011 | Train Loss: 1.5481 | Val Loss: 1.0908 | Train Acc: 0.6601 | Val Acc: 0.6406
# Epoch 021 | Train Loss: 1.4445 | Val Loss: 1.0341 | Train Acc: 0.6745 | Val Acc: 0.6738
# Early stopping at epoch 29
# Fold 5 completed in 68.54 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.6819
#
# Trial 9/16: {'learning_rate': 0.01, 'l2_lambda': 0.01, 'batch_size': 64, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5190 | Val Loss: 3.4426 | Train Acc: 0.0651 | Val Acc: 0.0642
# Epoch 011 | Train Loss: 2.8004 | Val Loss: 2.4789 | Train Acc: 0.3076 | Val Acc: 0.2939
# Epoch 021 | Train Loss: 2.2980 | Val Loss: 1.9369 | Train Acc: 0.4397 | Val Acc: 0.4299
# Epoch 031 | Train Loss: 1.9961 | Val Loss: 1.6413 | Train Acc: 0.5211 | Val Acc: 0.5171
# Epoch 041 | Train Loss: 1.7987 | Val Loss: 1.4620 | Train Acc: 0.5670 | Val Acc: 0.5789
# Epoch 051 | Train Loss: 1.6391 | Val Loss: 1.3633 | Train Acc: 0.5866 | Val Acc: 0.5837
# Epoch 061 | Train Loss: 1.5227 | Val Loss: 1.2123 | Train Acc: 0.6475 | Val Acc: 0.6372
# Epoch 071 | Train Loss: 1.4198 | Val Loss: 1.1280 | Train Acc: 0.6661 | Val Acc: 0.6659
# Epoch 081 | Train Loss: 1.3572 | Val Loss: 1.0459 | Train Acc: 0.6957 | Val Acc: 0.6863
# Epoch 091 | Train Loss: 1.2783 | Val Loss: 1.0014 | Train Acc: 0.7097 | Val Acc: 0.6957
# Epoch 100 | Train Loss: 1.2249 | Val Loss: 0.9518 | Train Acc: 0.7238 | Val Acc: 0.7120
# Fold 1 completed in 214.49 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5195 | Val Loss: 3.4424 | Train Acc: 0.0573 | Val Acc: 0.0594
# Epoch 011 | Train Loss: 2.7849 | Val Loss: 2.4595 | Train Acc: 0.3319 | Val Acc: 0.3131
# Epoch 021 | Train Loss: 2.3093 | Val Loss: 1.9292 | Train Acc: 0.4464 | Val Acc: 0.4382
# Epoch 031 | Train Loss: 1.9965 | Val Loss: 1.6470 | Train Acc: 0.5225 | Val Acc: 0.5080
# Epoch 041 | Train Loss: 1.8100 | Val Loss: 1.4590 | Train Acc: 0.5810 | Val Acc: 0.5719
# Epoch 051 | Train Loss: 1.6681 | Val Loss: 1.3252 | Train Acc: 0.6092 | Val Acc: 0.6035
# Epoch 061 | Train Loss: 1.5443 | Val Loss: 1.2084 | Train Acc: 0.6504 | Val Acc: 0.6416
# Epoch 071 | Train Loss: 1.4550 | Val Loss: 1.1377 | Train Acc: 0.6598 | Val Acc: 0.6461
# Epoch 081 | Train Loss: 1.3700 | Val Loss: 1.0663 | Train Acc: 0.6780 | Val Acc: 0.6641
# Epoch 091 | Train Loss: 1.3213 | Val Loss: 1.0096 | Train Acc: 0.7026 | Val Acc: 0.6934
# Epoch 100 | Train Loss: 1.2601 | Val Loss: 0.9671 | Train Acc: 0.7117 | Val Acc: 0.6904
# Fold 2 completed in 214.12 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5177 | Val Loss: 3.4414 | Train Acc: 0.0631 | Val Acc: 0.0544
# Epoch 011 | Train Loss: 2.8004 | Val Loss: 2.4017 | Train Acc: 0.3297 | Val Acc: 0.3229
# Epoch 021 | Train Loss: 2.3038 | Val Loss: 1.8859 | Train Acc: 0.4457 | Val Acc: 0.4556
# Epoch 031 | Train Loss: 1.9925 | Val Loss: 1.6068 | Train Acc: 0.5251 | Val Acc: 0.5313
# Epoch 041 | Train Loss: 1.7928 | Val Loss: 1.4295 | Train Acc: 0.5778 | Val Acc: 0.5784
# Epoch 051 | Train Loss: 1.6494 | Val Loss: 1.3233 | Train Acc: 0.5996 | Val Acc: 0.5946
# Epoch 061 | Train Loss: 1.5237 | Val Loss: 1.2050 | Train Acc: 0.6424 | Val Acc: 0.6342
# Epoch 071 | Train Loss: 1.4433 | Val Loss: 1.1238 | Train Acc: 0.6618 | Val Acc: 0.6449
# Epoch 081 | Train Loss: 1.3482 | Val Loss: 1.0093 | Train Acc: 0.7014 | Val Acc: 0.6886
# Epoch 091 | Train Loss: 1.2917 | Val Loss: 0.9534 | Train Acc: 0.7195 | Val Acc: 0.7079
# Epoch 100 | Train Loss: 1.2224 | Val Loss: 0.9479 | Train Acc: 0.7166 | Val Acc: 0.6907
# Fold 3 completed in 213.36 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5185 | Val Loss: 3.4491 | Train Acc: 0.0603 | Val Acc: 0.0553
# Epoch 011 | Train Loss: 2.7902 | Val Loss: 2.4827 | Train Acc: 0.3302 | Val Acc: 0.3100
# Epoch 021 | Train Loss: 2.2772 | Val Loss: 1.9412 | Train Acc: 0.4637 | Val Acc: 0.4451
# Epoch 031 | Train Loss: 1.9898 | Val Loss: 1.6761 | Train Acc: 0.5383 | Val Acc: 0.5114
# Epoch 041 | Train Loss: 1.7871 | Val Loss: 1.4901 | Train Acc: 0.5842 | Val Acc: 0.5608
# Epoch 051 | Train Loss: 1.6497 | Val Loss: 1.3678 | Train Acc: 0.6179 | Val Acc: 0.5930
# Epoch 061 | Train Loss: 1.5448 | Val Loss: 1.2783 | Train Acc: 0.6361 | Val Acc: 0.6122
# Epoch 071 | Train Loss: 1.4324 | Val Loss: 1.1762 | Train Acc: 0.6642 | Val Acc: 0.6430
# Epoch 081 | Train Loss: 1.3693 | Val Loss: 1.1059 | Train Acc: 0.6761 | Val Acc: 0.6599
# Epoch 091 | Train Loss: 1.3019 | Val Loss: 1.0475 | Train Acc: 0.6971 | Val Acc: 0.6773
# Epoch 100 | Train Loss: 1.2512 | Val Loss: 0.9853 | Train Acc: 0.7137 | Val Acc: 0.6977
# Fold 4 completed in 213.72 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5171 | Val Loss: 3.4393 | Train Acc: 0.0611 | Val Acc: 0.0648
# Epoch 011 | Train Loss: 2.8036 | Val Loss: 2.4360 | Train Acc: 0.3262 | Val Acc: 0.3274
# Epoch 021 | Train Loss: 2.2943 | Val Loss: 1.9231 | Train Acc: 0.4484 | Val Acc: 0.4377
# Epoch 031 | Train Loss: 2.0069 | Val Loss: 1.6476 | Train Acc: 0.5342 | Val Acc: 0.5209
# Epoch 041 | Train Loss: 1.8115 | Val Loss: 1.4688 | Train Acc: 0.5600 | Val Acc: 0.5534
# Epoch 051 | Train Loss: 1.6508 | Val Loss: 1.3341 | Train Acc: 0.6088 | Val Acc: 0.5969
# Epoch 061 | Train Loss: 1.5522 | Val Loss: 1.2017 | Train Acc: 0.6407 | Val Acc: 0.6460
# Epoch 071 | Train Loss: 1.4523 | Val Loss: 1.1072 | Train Acc: 0.6622 | Val Acc: 0.6652
# Epoch 081 | Train Loss: 1.3931 | Val Loss: 1.0489 | Train Acc: 0.6817 | Val Acc: 0.6883
# Epoch 091 | Train Loss: 1.3072 | Val Loss: 0.9712 | Train Acc: 0.6996 | Val Acc: 0.6968
# Epoch 100 | Train Loss: 1.2640 | Val Loss: 0.9323 | Train Acc: 0.7098 | Val Acc: 0.7137
# Fold 5 completed in 212.99 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.7009
#
# Trial 10/16: {'learning_rate': 0.01, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'adam'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 2.6436 | Val Loss: 1.9160 | Train Acc: 0.3858 | Val Acc: 0.3717
# Epoch 011 | Train Loss: 1.7102 | Val Loss: 1.3792 | Train Acc: 0.5579 | Val Acc: 0.5405
# Epoch 021 | Train Loss: 1.6288 | Val Loss: 1.3209 | Train Acc: 0.5772 | Val Acc: 0.5568
# Epoch 031 | Train Loss: 1.5817 | Val Loss: 1.1941 | Train Acc: 0.6056 | Val Acc: 0.5970
# Epoch 041 | Train Loss: 1.5553 | Val Loss: 1.1416 | Train Acc: 0.6289 | Val Acc: 0.6189
# Early stopping at epoch 51
# Fold 1 completed in 281.56 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 2.6809 | Val Loss: 1.9051 | Train Acc: 0.4020 | Val Acc: 0.3879
# Epoch 011 | Train Loss: 1.7311 | Val Loss: 1.3541 | Train Acc: 0.5656 | Val Acc: 0.5444
# Epoch 021 | Train Loss: 1.6322 | Val Loss: 1.2334 | Train Acc: 0.6027 | Val Acc: 0.5955
# Epoch 031 | Train Loss: 1.5806 | Val Loss: 1.2211 | Train Acc: 0.6037 | Val Acc: 0.5899
# Epoch 041 | Train Loss: 1.5856 | Val Loss: 1.2408 | Train Acc: 0.6145 | Val Acc: 0.5970
# Early stopping at epoch 42
# Fold 2 completed in 180.87 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 2.6913 | Val Loss: 1.9789 | Train Acc: 0.3620 | Val Acc: 0.3590
# Epoch 011 | Train Loss: 1.7286 | Val Loss: 1.3437 | Train Acc: 0.5566 | Val Acc: 0.5550
# Epoch 021 | Train Loss: 1.6168 | Val Loss: 1.2518 | Train Acc: 0.5874 | Val Acc: 0.5837
# Epoch 031 | Train Loss: 1.5811 | Val Loss: 1.2288 | Train Acc: 0.5995 | Val Acc: 0.6023
# Epoch 041 | Train Loss: 1.5722 | Val Loss: 1.1816 | Train Acc: 0.6056 | Val Acc: 0.6070
# Early stopping at epoch 49
# Fold 3 completed in 262.65 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 2.6737 | Val Loss: 1.8633 | Train Acc: 0.4045 | Val Acc: 0.3863
# Epoch 011 | Train Loss: 1.7053 | Val Loss: 1.4425 | Train Acc: 0.5473 | Val Acc: 0.5282
# Epoch 021 | Train Loss: 1.5993 | Val Loss: 1.3062 | Train Acc: 0.6169 | Val Acc: 0.5883
# Epoch 031 | Train Loss: 1.5661 | Val Loss: 1.1893 | Train Acc: 0.6333 | Val Acc: 0.6193
# Epoch 041 | Train Loss: 1.5030 | Val Loss: 1.2162 | Train Acc: 0.6265 | Val Acc: 0.6217
# Epoch 051 | Train Loss: 1.5229 | Val Loss: 1.1835 | Train Acc: 0.6385 | Val Acc: 0.6149
# Epoch 061 | Train Loss: 1.5076 | Val Loss: 1.1235 | Train Acc: 0.6525 | Val Acc: 0.6327
# Early stopping at epoch 66
# Fold 4 completed in 459.92 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 2.6178 | Val Loss: 1.8239 | Train Acc: 0.4144 | Val Acc: 0.4096
# Epoch 011 | Train Loss: 1.6619 | Val Loss: 1.3894 | Train Acc: 0.5615 | Val Acc: 0.5318
# Epoch 021 | Train Loss: 1.5764 | Val Loss: 1.2601 | Train Acc: 0.5965 | Val Acc: 0.5877
# Epoch 031 | Train Loss: 1.5485 | Val Loss: 1.2477 | Train Acc: 0.6162 | Val Acc: 0.6128
# Epoch 041 | Train Loss: 1.5338 | Val Loss: 1.2284 | Train Acc: 0.6109 | Val Acc: 0.6108
# Epoch 051 | Train Loss: 1.5009 | Val Loss: 1.1476 | Train Acc: 0.6287 | Val Acc: 0.6256
# Early stopping at epoch 57
# Fold 5 completed in 351.05 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.6198
#
# Trial 11/16: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5257 | Val Loss: 3.5096 | Train Acc: 0.0312 | Val Acc: 0.0322
# Epoch 011 | Train Loss: 3.3961 | Val Loss: 3.3487 | Train Acc: 0.0848 | Val Acc: 0.0804
# Epoch 021 | Train Loss: 3.2496 | Val Loss: 3.1488 | Train Acc: 0.1394 | Val Acc: 0.1263
# Epoch 031 | Train Loss: 3.0943 | Val Loss: 2.9283 | Train Acc: 0.1898 | Val Acc: 0.1818
# Epoch 041 | Train Loss: 2.9472 | Val Loss: 2.7098 | Train Acc: 0.2523 | Val Acc: 0.2428
# Epoch 051 | Train Loss: 2.7873 | Val Loss: 2.5105 | Train Acc: 0.3097 | Val Acc: 0.2948
# Epoch 061 | Train Loss: 2.6659 | Val Loss: 2.3492 | Train Acc: 0.3557 | Val Acc: 0.3374
# Epoch 071 | Train Loss: 2.5496 | Val Loss: 2.2194 | Train Acc: 0.3874 | Val Acc: 0.3658
# Epoch 081 | Train Loss: 2.4567 | Val Loss: 2.1102 | Train Acc: 0.4091 | Val Acc: 0.3856
# Epoch 091 | Train Loss: 2.3524 | Val Loss: 2.0153 | Train Acc: 0.4343 | Val Acc: 0.4098
# Epoch 100 | Train Loss: 2.2764 | Val Loss: 1.9377 | Train Acc: 0.4462 | Val Acc: 0.4302
# Fold 1 completed in 258.12 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5258 | Val Loss: 3.5082 | Train Acc: 0.0302 | Val Acc: 0.0316
# Epoch 011 | Train Loss: 3.4053 | Val Loss: 3.3474 | Train Acc: 0.0831 | Val Acc: 0.0887
# Epoch 021 | Train Loss: 3.2564 | Val Loss: 3.1355 | Train Acc: 0.1428 | Val Acc: 0.1422
# Epoch 031 | Train Loss: 3.0907 | Val Loss: 2.9131 | Train Acc: 0.1910 | Val Acc: 0.1925
# Epoch 041 | Train Loss: 2.9296 | Val Loss: 2.6950 | Train Acc: 0.2655 | Val Acc: 0.2558
# ...
# Epoch 071 | Train Loss: 1.0726 | Val Loss: 0.8531 | Train Acc: 0.7389 | Val Acc: 0.7309
# Epoch 081 | Train Loss: 1.0091 | Val Loss: 0.7871 | Train Acc: 0.7645 | Val Acc: 0.7416
# Epoch 091 | Train Loss: 0.9766 | Val Loss: 0.7560 | Train Acc: 0.7742 | Val Acc: 0.7561
# Epoch 100 | Train Loss: 0.9376 | Val Loss: 0.7284 | Train Acc: 0.7857 | Val Acc: 0.7691
# Fold 2 completed in 254.29 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.4681 | Val Loss: 3.3641 | Train Acc: 0.0804 | Val Acc: 0.0775
# Epoch 011 | Train Loss: 2.2823 | Val Loss: 1.8583 | Train Acc: 0.4534 | Val Acc: 0.4595
# Epoch 021 | Train Loss: 1.7721 | Val Loss: 1.4440 | Train Acc: 0.5535 | Val Acc: 0.5556
# Epoch 031 | Train Loss: 1.5072 | Val Loss: 1.1943 | Train Acc: 0.6419 | Val Acc: 0.6339
# Epoch 041 | Train Loss: 1.3327 | Val Loss: 1.0339 | Train Acc: 0.6947 | Val Acc: 0.6842
# Epoch 051 | Train Loss: 1.2199 | Val Loss: 0.9592 | Train Acc: 0.7105 | Val Acc: 0.6931
# Epoch 061 | Train Loss: 1.1243 | Val Loss: 0.8739 | Train Acc: 0.7368 | Val Acc: 0.7268
# Epoch 071 | Train Loss: 1.0732 | Val Loss: 0.8213 | Train Acc: 0.7570 | Val Acc: 0.7371
# Epoch 081 | Train Loss: 1.0034 | Val Loss: 0.7375 | Train Acc: 0.7780 | Val Acc: 0.7700
# Epoch 091 | Train Loss: 0.9683 | Val Loss: 0.7178 | Train Acc: 0.7835 | Val Acc: 0.7670
# Epoch 100 | Train Loss: 0.9210 | Val Loss: 0.7077 | Train Acc: 0.7862 | Val Acc: 0.7694
# Fold 3 completed in 254.12 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.4722 | Val Loss: 3.3861 | Train Acc: 0.0790 | Val Acc: 0.0736
# Epoch 011 | Train Loss: 2.2475 | Val Loss: 1.9088 | Train Acc: 0.4662 | Val Acc: 0.4460
# Epoch 021 | Train Loss: 1.7424 | Val Loss: 1.4522 | Train Acc: 0.5868 | Val Acc: 0.5694
# Epoch 031 | Train Loss: 1.4920 | Val Loss: 1.2214 | Train Acc: 0.6527 | Val Acc: 0.6389
# Epoch 041 | Train Loss: 1.3099 | Val Loss: 1.0455 | Train Acc: 0.6963 | Val Acc: 0.6826
# Epoch 051 | Train Loss: 1.2065 | Val Loss: 0.9681 | Train Acc: 0.7124 | Val Acc: 0.7016
# Epoch 061 | Train Loss: 1.1215 | Val Loss: 0.9342 | Train Acc: 0.7088 | Val Acc: 0.7025
# Epoch 071 | Train Loss: 1.0531 | Val Loss: 0.8311 | Train Acc: 0.7465 | Val Acc: 0.7471
# Epoch 081 | Train Loss: 1.0147 | Val Loss: 0.7948 | Train Acc: 0.7536 | Val Acc: 0.7468
# Epoch 091 | Train Loss: 0.9466 | Val Loss: 0.7602 | Train Acc: 0.7686 | Val Acc: 0.7669
# Epoch 100 | Train Loss: 0.9132 | Val Loss: 0.6927 | Train Acc: 0.7925 | Val Acc: 0.7859
# Fold 4 completed in 252.34 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.4658 | Val Loss: 3.3580 | Train Acc: 0.0883 | Val Acc: 0.0914
# Epoch 011 | Train Loss: 2.3060 | Val Loss: 1.9149 | Train Acc: 0.4580 | Val Acc: 0.4587
# Epoch 021 | Train Loss: 1.7999 | Val Loss: 1.4781 | Train Acc: 0.5675 | Val Acc: 0.5611
# Epoch 031 | Train Loss: 1.5551 | Val Loss: 1.2281 | Train Acc: 0.6357 | Val Acc: 0.6312
# Epoch 041 | Train Loss: 1.3812 | Val Loss: 1.0866 | Train Acc: 0.6610 | Val Acc: 0.6625
# Epoch 051 | Train Loss: 1.2479 | Val Loss: 0.9518 | Train Acc: 0.7058 | Val Acc: 0.7096
# Epoch 061 | Train Loss: 1.1641 | Val Loss: 0.8558 | Train Acc: 0.7325 | Val Acc: 0.7326
# Epoch 071 | Train Loss: 1.0951 | Val Loss: 0.7952 | Train Acc: 0.7526 | Val Acc: 0.7560
# Epoch 081 | Train Loss: 1.0459 | Val Loss: 0.7820 | Train Acc: 0.7459 | Val Acc: 0.7507
# Epoch 091 | Train Loss: 0.9838 | Val Loss: 0.7354 | Train Acc: 0.7622 | Val Acc: 0.7684
# Epoch 100 | Train Loss: 0.9373 | Val Loss: 0.7072 | Train Acc: 0.7749 | Val Acc: 0.7693
# Fold 5 completed in 256.08 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.7744
#
# Trial 14/16: {'learning_rate': 0.001, 'l2_lambda': 0.01, 'batch_size': 32, 'optimizer': 'sgd'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5608 | Val Loss: 3.5099 | Train Acc: 0.0312 | Val Acc: 0.0322
# Epoch 011 | Train Loss: 3.4316 | Val Loss: 3.3496 | Train Acc: 0.0850 | Val Acc: 0.0804
# Epoch 021 | Train Loss: 3.2859 | Val Loss: 3.1504 | Train Acc: 0.1394 | Val Acc: 0.1257
# Epoch 031 | Train Loss: 3.1317 | Val Loss: 2.9310 | Train Acc: 0.1893 | Val Acc: 0.1807
# Epoch 041 | Train Loss: 2.9859 | Val Loss: 2.7135 | Train Acc: 0.2516 | Val Acc: 0.2422
# Epoch 051 | Train Loss: 2.8279 | Val Loss: 2.5151 | Train Acc: 0.3082 | Val Acc: 0.2936
# Epoch 061 | Train Loss: 2.7082 | Val Loss: 2.3545 | Train Acc: 0.3550 | Val Acc: 0.3368
# Epoch 071 | Train Loss: 2.5935 | Val Loss: 2.2251 | Train Acc: 0.3858 | Val Acc: 0.3646
# Epoch 081 | Train Loss: 2.5021 | Val Loss: 2.1167 | Train Acc: 0.4082 | Val Acc: 0.3859
# Epoch 091 | Train Loss: 2.3995 | Val Loss: 2.0223 | Train Acc: 0.4330 | Val Acc: 0.4080
# Epoch 100 | Train Loss: 2.3247 | Val Loss: 1.9449 | Train Acc: 0.4451 | Val Acc: 0.4281
# Fold 1 completed in 258.33 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5609 | Val Loss: 3.5086 | Train Acc: 0.0303 | Val Acc: 0.0316
# Epoch 011 | Train Loss: 3.4407 | Val Loss: 3.3481 | Train Acc: 0.0824 | Val Acc: 0.0896
# Epoch 021 | Train Loss: 3.2927 | Val Loss: 3.1373 | Train Acc: 0.1423 | Val Acc: 0.1422
# Epoch 031 | Train Loss: 3.1283 | Val Loss: 2.9159 | Train Acc: 0.1907 | Val Acc: 0.1919
# Epoch 041 | Train Loss: 2.9686 | Val Loss: 2.6988 | Train Acc: 0.2649 | Val Acc: 0.2540
# Epoch 051 | Train Loss: 2.8197 | Val Loss: 2.5067 | Train Acc: 0.3210 | Val Acc: 0.3099
# Epoch 061 | Train Loss: 2.6929 | Val Loss: 2.3521 | Train Acc: 0.3535 | Val Acc: 0.3445
# Epoch 071 | Train Loss: 2.5723 | Val Loss: 2.2248 | Train Acc: 0.3889 | Val Acc: 0.3811
# Epoch 081 | Train Loss: 2.4761 | Val Loss: 2.1197 | Train Acc: 0.4168 | Val Acc: 0.4063
# Epoch 091 | Train Loss: 2.3969 | Val Loss: 2.0242 | Train Acc: 0.4348 | Val Acc: 0.4240
# Epoch 100 | Train Loss: 2.3042 | Val Loss: 1.9485 | Train Acc: 0.4508 | Val Acc: 0.4367
# Fold 2 completed in 256.23 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5584 | Val Loss: 3.5084 | Train Acc: 0.0318 | Val Acc: 0.0266
# Epoch 011 | Train Loss: 3.4416 | Val Loss: 3.3443 | Train Acc: 0.0843 | Val Acc: 0.0789
# Epoch 021 | Train Loss: 3.2967 | Val Loss: 3.1263 | Train Acc: 0.1337 | Val Acc: 0.1342
# Epoch 031 | Train Loss: 3.1343 | Val Loss: 2.8900 | Train Acc: 0.1924 | Val Acc: 0.1916
# Epoch 041 | Train Loss: 2.9681 | Val Loss: 2.6567 | Train Acc: 0.2636 | Val Acc: 0.2567
# Epoch 051 | Train Loss: 2.8281 | Val Loss: 2.4560 | Train Acc: 0.3151 | Val Acc: 0.3137
# Epoch 061 | Train Loss: 2.6977 | Val Loss: 2.2959 | Train Acc: 0.3548 | Val Acc: 0.3522
# Epoch 071 | Train Loss: 2.5968 | Val Loss: 2.1707 | Train Acc: 0.3847 | Val Acc: 0.3930
# Epoch 081 | Train Loss: 2.4805 | Val Loss: 2.0590 | Train Acc: 0.4134 | Val Acc: 0.4311
# Epoch 091 | Train Loss: 2.3953 | Val Loss: 1.9678 | Train Acc: 0.4350 | Val Acc: 0.4491
# Epoch 100 | Train Loss: 2.3186 | Val Loss: 1.8953 | Train Acc: 0.4542 | Val Acc: 0.4698
# Fold 3 completed in 256.30 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5593 | Val Loss: 3.5079 | Train Acc: 0.0300 | Val Acc: 0.0316
# Epoch 011 | Train Loss: 3.4393 | Val Loss: 3.3539 | Train Acc: 0.0833 | Val Acc: 0.0840
# Epoch 021 | Train Loss: 3.2887 | Val Loss: 3.1495 | Train Acc: 0.1379 | Val Acc: 0.1293
# Epoch 031 | Train Loss: 3.1284 | Val Loss: 2.9316 | Train Acc: 0.1922 | Val Acc: 0.1798
# Epoch 041 | Train Loss: 2.9715 | Val Loss: 2.7213 | Train Acc: 0.2599 | Val Acc: 0.2473
# Epoch 051 | Train Loss: 2.8217 | Val Loss: 2.5310 | Train Acc: 0.3171 | Val Acc: 0.3120
# Epoch 061 | Train Loss: 2.6910 | Val Loss: 2.3782 | Train Acc: 0.3543 | Val Acc: 0.3392
# Epoch 071 | Train Loss: 2.5713 | Val Loss: 2.2519 | Train Acc: 0.3890 | Val Acc: 0.3697
# Epoch 081 | Train Loss: 2.4791 | Val Loss: 2.1458 | Train Acc: 0.4121 | Val Acc: 0.3934
# Epoch 091 | Train Loss: 2.3880 | Val Loss: 2.0526 | Train Acc: 0.4309 | Val Acc: 0.4114
# Epoch 100 | Train Loss: 2.3164 | Val Loss: 1.9756 | Train Acc: 0.4515 | Val Acc: 0.4336
# Fold 4 completed in 256.98 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5581 | Val Loss: 3.5116 | Train Acc: 0.0302 | Val Acc: 0.0302
# Epoch 011 | Train Loss: 3.4403 | Val Loss: 3.3458 | Train Acc: 0.0830 | Val Acc: 0.0840
# Epoch 021 | Train Loss: 3.2949 | Val Loss: 3.1350 | Train Acc: 0.1401 | Val Acc: 0.1429
# Epoch 031 | Train Loss: 3.1374 | Val Loss: 2.9054 | Train Acc: 0.1893 | Val Acc: 0.1937
# Epoch 041 | Train Loss: 2.9772 | Val Loss: 2.6892 | Train Acc: 0.2477 | Val Acc: 0.2555
# Epoch 051 | Train Loss: 2.8245 | Val Loss: 2.4909 | Train Acc: 0.3052 | Val Acc: 0.3162
# Epoch 061 | Train Loss: 2.6931 | Val Loss: 2.3327 | Train Acc: 0.3491 | Val Acc: 0.3526
# Epoch 071 | Train Loss: 2.5803 | Val Loss: 2.2071 | Train Acc: 0.3888 | Val Acc: 0.3898
# Epoch 081 | Train Loss: 2.4877 | Val Loss: 2.1010 | Train Acc: 0.4115 | Val Acc: 0.4164
# Epoch 091 | Train Loss: 2.4040 | Val Loss: 2.0098 | Train Acc: 0.4319 | Val Acc: 0.4315
# Epoch 100 | Train Loss: 2.3158 | Val Loss: 1.9351 | Train Acc: 0.4541 | Val Acc: 0.4451
# Fold 5 completed in 253.70 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.4427
#
# Trial 15/16: {'learning_rate': 0.01, 'l2_lambda': 0.01, 'batch_size': 64, 'optimizer': 'adam'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 2.7359 | Val Loss: 1.9781 | Train Acc: 0.3896 | Val Acc: 0.3823
# Epoch 011 | Train Loss: 1.6377 | Val Loss: 1.1409 | Train Acc: 0.6230 | Val Acc: 0.6183
# Epoch 021 | Train Loss: 1.5026 | Val Loss: 1.0710 | Train Acc: 0.6556 | Val Acc: 0.6493
# Epoch 031 | Train Loss: 1.4375 | Val Loss: 1.0664 | Train Acc: 0.6635 | Val Acc: 0.6532
# Epoch 041 | Train Loss: 1.3917 | Val Loss: 0.9772 | Train Acc: 0.6776 | Val Acc: 0.6659
# Epoch 051 | Train Loss: 1.3801 | Val Loss: 1.0226 | Train Acc: 0.6939 | Val Acc: 0.6750
# Early stopping at epoch 52
# Fold 1 completed in 133.26 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 2.7227 | Val Loss: 1.9287 | Train Acc: 0.4083 | Val Acc: 0.4051
# Epoch 011 | Train Loss: 1.6600 | Val Loss: 1.2245 | Train Acc: 0.6096 | Val Acc: 0.5905
# Epoch 021 | Train Loss: 1.5523 | Val Loss: 1.0794 | Train Acc: 0.6496 | Val Acc: 0.6390
# Epoch 031 | Train Loss: 1.4733 | Val Loss: 1.0477 | Train Acc: 0.6618 | Val Acc: 0.6484
# Epoch 041 | Train Loss: 1.4462 | Val Loss: 1.1329 | Train Acc: 0.6488 | Val Acc: 0.6277
# Early stopping at epoch 46
# Fold 2 completed in 115.56 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 2.6544 | Val Loss: 1.7293 | Train Acc: 0.4457 | Val Acc: 0.4358
# Epoch 011 | Train Loss: 1.5360 | Val Loss: 1.1573 | Train Acc: 0.6209 | Val Acc: 0.6283
# Epoch 021 | Train Loss: 1.4256 | Val Loss: 0.9946 | Train Acc: 0.6851 | Val Acc: 0.6789
# Epoch 031 | Train Loss: 1.3829 | Val Loss: 0.9114 | Train Acc: 0.6969 | Val Acc: 0.6963
# Epoch 041 | Train Loss: 1.3424 | Val Loss: 0.8411 | Train Acc: 0.7333 | Val Acc: 0.7247
# Early stopping at epoch 44
# Fold 3 completed in 110.42 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 2.7262 | Val Loss: 1.8641 | Train Acc: 0.4028 | Val Acc: 0.3957
# Epoch 011 | Train Loss: 1.5832 | Val Loss: 1.2155 | Train Acc: 0.6163 | Val Acc: 0.6019
# Epoch 021 | Train Loss: 1.4829 | Val Loss: 1.0658 | Train Acc: 0.6705 | Val Acc: 0.6628
# Epoch 031 | Train Loss: 1.4088 | Val Loss: 0.9445 | Train Acc: 0.6976 | Val Acc: 0.6930
# Epoch 041 | Train Loss: 1.3629 | Val Loss: 0.9277 | Train Acc: 0.7084 | Val Acc: 0.6924
# Epoch 051 | Train Loss: 1.3595 | Val Loss: 1.0037 | Train Acc: 0.6926 | Val Acc: 0.6749
# Early stopping at epoch 55
# Fold 4 completed in 135.53 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 2.7330 | Val Loss: 1.8498 | Train Acc: 0.4039 | Val Acc: 0.4061
# Epoch 011 | Train Loss: 1.5481 | Val Loss: 1.0908 | Train Acc: 0.6601 | Val Acc: 0.6406
# Epoch 021 | Train Loss: 1.4445 | Val Loss: 1.0341 | Train Acc: 0.6745 | Val Acc: 0.6738
# Early stopping at epoch 29
# Fold 5 completed in 74.28 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.6819
#
# Trial 16/16: {'learning_rate': 0.001, 'l2_lambda': 0.01, 'batch_size': 64, 'optimizer': 'adam'}
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.1062 | Val Loss: 2.3979 | Train Acc: 0.3253 | Val Acc: 0.3048
# Epoch 011 | Train Loss: 1.3852 | Val Loss: 1.0793 | Train Acc: 0.6802 | Val Acc: 0.6656
# Epoch 021 | Train Loss: 1.1525 | Val Loss: 0.9003 | Train Acc: 0.7338 | Val Acc: 0.7120
# Epoch 031 | Train Loss: 1.0224 | Val Loss: 0.7512 | Train Acc: 0.7825 | Val Acc: 0.7655
# Epoch 041 | Train Loss: 0.9599 | Val Loss: 0.6822 | Train Acc: 0.8062 | Val Acc: 0.7865
# Epoch 051 | Train Loss: 0.9065 | Val Loss: 0.6882 | Train Acc: 0.8008 | Val Acc: 0.7806
# Epoch 061 | Train Loss: 0.8665 | Val Loss: 0.6450 | Train Acc: 0.8180 | Val Acc: 0.7995
# Epoch 071 | Train Loss: 0.8438 | Val Loss: 0.6217 | Train Acc: 0.8199 | Val Acc: 0.8102
# Epoch 081 | Train Loss: 0.8246 | Val Loss: 0.5900 | Train Acc: 0.8345 | Val Acc: 0.8193
# Epoch 091 | Train Loss: 0.7939 | Val Loss: 0.5762 | Train Acc: 0.8381 | Val Acc: 0.8176
# Epoch 100 | Train Loss: 0.7704 | Val Loss: 0.5688 | Train Acc: 0.8447 | Val Acc: 0.8255
# Fold 1 completed in 249.32 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.1104 | Val Loss: 2.3658 | Train Acc: 0.3427 | Val Acc: 0.3185
# Epoch 011 | Train Loss: 1.3507 | Val Loss: 1.0711 | Train Acc: 0.6718 | Val Acc: 0.6549
# Epoch 021 | Train Loss: 1.1221 | Val Loss: 0.8164 | Train Acc: 0.7502 | Val Acc: 0.7380
# Epoch 031 | Train Loss: 1.0111 | Val Loss: 0.7697 | Train Acc: 0.7696 | Val Acc: 0.7472
# Epoch 041 | Train Loss: 0.9402 | Val Loss: 0.6846 | Train Acc: 0.7976 | Val Acc: 0.7753
# Epoch 051 | Train Loss: 0.8958 | Val Loss: 0.6207 | Train Acc: 0.8127 | Val Acc: 0.8051
# Epoch 061 | Train Loss: 0.8553 | Val Loss: 0.6297 | Train Acc: 0.8146 | Val Acc: 0.7933
# Epoch 071 | Train Loss: 0.8296 | Val Loss: 0.5881 | Train Acc: 0.8214 | Val Acc: 0.8108
# Epoch 081 | Train Loss: 0.7889 | Val Loss: 0.5239 | Train Acc: 0.8422 | Val Acc: 0.8335
# Epoch 091 | Train Loss: 0.7824 | Val Loss: 0.5272 | Train Acc: 0.8450 | Val Acc: 0.8294
# Epoch 100 | Train Loss: 0.7613 | Val Loss: 0.5142 | Train Acc: 0.8454 | Val Acc: 0.8326
# Fold 2 completed in 249.41 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.0900 | Val Loss: 2.3371 | Train Acc: 0.3195 | Val Acc: 0.3391
# Epoch 011 | Train Loss: 1.3702 | Val Loss: 1.0411 | Train Acc: 0.6835 | Val Acc: 0.6792
# Epoch 021 | Train Loss: 1.1381 | Val Loss: 0.8341 | Train Acc: 0.7499 | Val Acc: 0.7383
# Epoch 031 | Train Loss: 1.0417 | Val Loss: 0.7342 | Train Acc: 0.7734 | Val Acc: 0.7649
# Epoch 041 | Train Loss: 0.9873 | Val Loss: 0.6847 | Train Acc: 0.7916 | Val Acc: 0.7762
# Epoch 051 | Train Loss: 0.9376 | Val Loss: 0.6484 | Train Acc: 0.7965 | Val Acc: 0.7856
# Epoch 061 | Train Loss: 0.8936 | Val Loss: 0.6098 | Train Acc: 0.8131 | Val Acc: 0.8034
# Epoch 071 | Train Loss: 0.8619 | Val Loss: 0.6165 | Train Acc: 0.8125 | Val Acc: 0.7939
# Epoch 081 | Train Loss: 0.8369 | Val Loss: 0.5644 | Train Acc: 0.8240 | Val Acc: 0.8099
# Early stopping at epoch 85
# Fold 3 completed in 207.65 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.1062 | Val Loss: 2.3915 | Train Acc: 0.3360 | Val Acc: 0.3194
# Epoch 011 | Train Loss: 1.3586 | Val Loss: 1.0449 | Train Acc: 0.6936 | Val Acc: 0.6687
# Epoch 021 | Train Loss: 1.1179 | Val Loss: 0.8367 | Train Acc: 0.7529 | Val Acc: 0.7385
# Epoch 031 | Train Loss: 0.9898 | Val Loss: 0.7453 | Train Acc: 0.7676 | Val Acc: 0.7634
# Epoch 041 | Train Loss: 0.9232 | Val Loss: 0.6461 | Train Acc: 0.8059 | Val Acc: 0.7933
# Epoch 051 | Train Loss: 0.8798 | Val Loss: 0.6270 | Train Acc: 0.8146 | Val Acc: 0.7989
# Epoch 061 | Train Loss: 0.8390 | Val Loss: 0.6087 | Train Acc: 0.8214 | Val Acc: 0.8066
# Epoch 071 | Train Loss: 0.8044 | Val Loss: 0.5600 | Train Acc: 0.8374 | Val Acc: 0.8175
# Early stopping at epoch 74
# Fold 4 completed in 184.69 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.1030 | Val Loss: 2.4030 | Train Acc: 0.3237 | Val Acc: 0.3227
# Epoch 011 | Train Loss: 1.3693 | Val Loss: 1.0479 | Train Acc: 0.6778 | Val Acc: 0.6738
# Epoch 021 | Train Loss: 1.1256 | Val Loss: 0.8159 | Train Acc: 0.7510 | Val Acc: 0.7465
# Epoch 031 | Train Loss: 1.0250 | Val Loss: 0.7202 | Train Acc: 0.7831 | Val Acc: 0.7817
# Epoch 041 | Train Loss: 0.9591 | Val Loss: 0.6687 | Train Acc: 0.7953 | Val Acc: 0.7844
# Early stopping at epoch 50
# Fold 5 completed in 123.88 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.8142
#
# ======================================== Random Search's result: ==================================
#
# Best parameters: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'adam'}
# Best validation accuracy: 0.8293

# %%
learning_rate = best_params['learning_rate']
l2_lambda = best_params['l2_lambda']
batch_size = best_params['batch_size']
optimizer = best_params['optimizer']

# %% [markdown]
# ## **9.Perform k-fold cross-validation with SGD & Adam**

# %% [markdown]
# ### **9.1.Perform k-fold cross-validation with SGD**

# %%
print("\nK-Fold Cross-Validation with SGD (Augmented):")
avg_train_losses_sgd, avg_val_losses_sgd, avg_train_accuracies_sgd, avg_val_accuracies_sgd = k_fold_cross_validation(
    X_train, y_train_one_hot, layer_sizes, k=5, epochs=100, batch_size=batch_size, learning_rate=learning_rate, l2_lambda=l2_lambda, optimizer='sgd', augment=True
)
# Out:
# K-Fold Cross-Validation with SGD (Augmented):
#
# Fold 1/5
# Epoch 001 | Train Loss: 3.5257 | Val Loss: 3.5096 | Train Acc: 0.0312 | Val Acc: 0.0322
# Epoch 011 | Train Loss: 3.3961 | Val Loss: 3.3487 | Train Acc: 0.0848 | Val Acc: 0.0804
# Epoch 021 | Train Loss: 3.2496 | Val Loss: 3.1488 | Train Acc: 0.1394 | Val Acc: 0.1263
# Epoch 031 | Train Loss: 3.0943 | Val Loss: 2.9283 | Train Acc: 0.1898 | Val Acc: 0.1818
# Epoch 041 | Train Loss: 2.9472 | Val Loss: 2.7098 | Train Acc: 0.2523 | Val Acc: 0.2428
# Epoch 051 | Train Loss: 2.7873 | Val Loss: 2.5105 | Train Acc: 0.3097 | Val Acc: 0.2948
# Epoch 061 | Train Loss: 2.6659 | Val Loss: 2.3492 | Train Acc: 0.3557 | Val Acc: 0.3374
# Epoch 071 | Train Loss: 2.5496 | Val Loss: 2.2194 | Train Acc: 0.3874 | Val Acc: 0.3658
# Epoch 081 | Train Loss: 2.4567 | Val Loss: 2.1102 | Train Acc: 0.4091 | Val Acc: 0.3856
# Epoch 091 | Train Loss: 2.3524 | Val Loss: 2.0153 | Train Acc: 0.4343 | Val Acc: 0.4098
# Epoch 100 | Train Loss: 2.2764 | Val Loss: 1.9377 | Train Acc: 0.4462 | Val Acc: 0.4302
# Fold 1 completed in 363.05 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 3.5258 | Val Loss: 3.5082 | Train Acc: 0.0302 | Val Acc: 0.0316
# Epoch 011 | Train Loss: 3.4053 | Val Loss: 3.3474 | Train Acc: 0.0831 | Val Acc: 0.0887
# Epoch 021 | Train Loss: 3.2564 | Val Loss: 3.1355 | Train Acc: 0.1428 | Val Acc: 0.1422
# Epoch 031 | Train Loss: 3.0907 | Val Loss: 2.9131 | Train Acc: 0.1910 | Val Acc: 0.1925
# Epoch 041 | Train Loss: 2.9296 | Val Loss: 2.6950 | Train Acc: 0.2655 | Val Acc: 0.2558
# Epoch 051 | Train Loss: 2.7791 | Val Loss: 2.5021 | Train Acc: 0.3218 | Val Acc: 0.3114
# Epoch 061 | Train Loss: 2.6506 | Val Loss: 2.3469 | Train Acc: 0.3543 | Val Acc: 0.3451
# Epoch 071 | Train Loss: 2.5282 | Val Loss: 2.2189 | Train Acc: 0.3904 | Val Acc: 0.3835
# Epoch 081 | Train Loss: 2.4305 | Val Loss: 2.1134 | Train Acc: 0.4174 | Val Acc: 0.4066
# Epoch 091 | Train Loss: 2.3500 | Val Loss: 2.0173 | Train Acc: 0.4365 | Val Acc: 0.4267
# Epoch 100 | Train Loss: 2.2557 | Val Loss: 1.9411 | Train Acc: 0.4512 | Val Acc: 0.4397
# Fold 2 completed in 311.03 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 3.5233 | Val Loss: 3.5081 | Train Acc: 0.0318 | Val Acc: 0.0266
# Epoch 011 | Train Loss: 3.4063 | Val Loss: 3.3436 | Train Acc: 0.0845 | Val Acc: 0.0789
# Epoch 021 | Train Loss: 3.2607 | Val Loss: 3.1248 | Train Acc: 0.1335 | Val Acc: 0.1348
# Epoch 031 | Train Loss: 3.0971 | Val Loss: 2.8875 | Train Acc: 0.1931 | Val Acc: 0.1922
# Epoch 041 | Train Loss: 2.9294 | Val Loss: 2.6532 | Train Acc: 0.2630 | Val Acc: 0.2561
# Epoch 051 | Train Loss: 2.7879 | Val Loss: 2.4519 | Train Acc: 0.3155 | Val Acc: 0.3134
# Epoch 061 | Train Loss: 2.6558 | Val Loss: 2.2908 | Train Acc: 0.3553 | Val Acc: 0.3527
# Epoch 071 | Train Loss: 2.5532 | Val Loss: 2.1651 | Train Acc: 0.3856 | Val Acc: 0.3930
# Epoch 081 | Train Loss: 2.4352 | Val Loss: 2.0530 | Train Acc: 0.4148 | Val Acc: 0.4320
# Epoch 091 | Train Loss: 2.3485 | Val Loss: 1.9615 | Train Acc: 0.4362 | Val Acc: 0.4506
# Epoch 100 | Train Loss: 2.2704 | Val Loss: 1.8883 | Train Acc: 0.4555 | Val Acc: 0.4710
# Fold 3 completed in 280.87 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 3.5242 | Val Loss: 3.5075 | Train Acc: 0.0301 | Val Acc: 0.0314
# Epoch 011 | Train Loss: 3.4038 | Val Loss: 3.3530 | Train Acc: 0.0832 | Val Acc: 0.0846
# Epoch 021 | Train Loss: 3.2521 | Val Loss: 3.1476 | Train Acc: 0.1381 | Val Acc: 0.1290
# Epoch 031 | Train Loss: 3.0904 | Val Loss: 2.9286 | Train Acc: 0.1927 | Val Acc: 0.1798
# Epoch 041 | Train Loss: 2.9320 | Val Loss: 2.7171 | Train Acc: 0.2605 | Val Acc: 0.2470
# Epoch 051 | Train Loss: 2.7808 | Val Loss: 2.5264 | Train Acc: 0.3177 | Val Acc: 0.3123
# Epoch 061 | Train Loss: 2.6486 | Val Loss: 2.3733 | Train Acc: 0.3553 | Val Acc: 0.3401
# Epoch 071 | Train Loss: 2.5272 | Val Loss: 2.2464 | Train Acc: 0.3903 | Val Acc: 0.3709
# Epoch 081 | Train Loss: 2.4335 | Val Loss: 2.1396 | Train Acc: 0.4131 | Val Acc: 0.3937
# Epoch 091 | Train Loss: 2.3411 | Val Loss: 2.0461 | Train Acc: 0.4318 | Val Acc: 0.4135
# Epoch 100 | Train Loss: 2.2679 | Val Loss: 1.9687 | Train Acc: 0.4526 | Val Acc: 0.4371
# Fold 4 completed in 277.69 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 3.5230 | Val Loss: 3.5113 | Train Acc: 0.0302 | Val Acc: 0.0302
# Epoch 011 | Train Loss: 3.4050 | Val Loss: 3.3452 | Train Acc: 0.0829 | Val Acc: 0.0840
# Epoch 021 | Train Loss: 3.2588 | Val Loss: 3.1335 | Train Acc: 0.1404 | Val Acc: 0.1432
# Epoch 031 | Train Loss: 3.1001 | Val Loss: 2.9029 | Train Acc: 0.1906 | Val Acc: 0.1934
# Epoch 041 | Train Loss: 2.9386 | Val Loss: 2.6858 | Train Acc: 0.2480 | Val Acc: 0.2564
# Epoch 051 | Train Loss: 2.7845 | Val Loss: 2.4870 | Train Acc: 0.3061 | Val Acc: 0.3159
# Epoch 061 | Train Loss: 2.6515 | Val Loss: 2.3283 | Train Acc: 0.3503 | Val Acc: 0.3529
# Epoch 071 | Train Loss: 2.5373 | Val Loss: 2.2024 | Train Acc: 0.3885 | Val Acc: 0.3910
# Epoch 081 | Train Loss: 2.4430 | Val Loss: 2.0957 | Train Acc: 0.4124 | Val Acc: 0.4153
# Epoch 091 | Train Loss: 2.3577 | Val Loss: 2.0039 | Train Acc: 0.4327 | Val Acc: 0.4321
# Epoch 100 | Train Loss: 2.2682 | Val Loss: 1.9287 | Train Acc: 0.4545 | Val Acc: 0.4454
# Fold 5 completed in 279.64 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.4447

# %% [markdown]
# ### **9.2.Perform k-fold cross-validation with Adam**

# %%
print("\nK-Fold Cross-Validation with Adam (Augmented):")
avg_train_losses_adam, avg_val_losses_adam, avg_train_accuracies_adam, avg_val_accuracies_adam = k_fold_cross_validation(
    X_train, y_train_one_hot, layer_sizes, k=5, epochs=100, batch_size=batch_size, learning_rate=learning_rate, l2_lambda=l2_lambda, optimizer='adam', augment=True
)
# Out:
# K-Fold Cross-Validation with Adam (Augmented):
#
# Fold 1/5
# Epoch 001 | Train Loss: 2.9324 | Val Loss: 2.1683 | Train Acc: 0.4083 | Val Acc: 0.3823
# Epoch 011 | Train Loss: 1.2396 | Val Loss: 0.9687 | Train Acc: 0.7133 | Val Acc: 0.6892
# Epoch 021 | Train Loss: 1.0223 | Val Loss: 0.7761 | Train Acc: 0.7730 | Val Acc: 0.7507
# Epoch 031 | Train Loss: 0.9056 | Val Loss: 0.6797 | Train Acc: 0.7921 | Val Acc: 0.7830
# Epoch 041 | Train Loss: 0.8357 | Val Loss: 0.6975 | Train Acc: 0.7978 | Val Acc: 0.7803
# Epoch 051 | Train Loss: 0.7965 | Val Loss: 0.6312 | Train Acc: 0.8091 | Val Acc: 0.7921
# Epoch 061 | Train Loss: 0.7593 | Val Loss: 0.5799 | Train Acc: 0.8297 | Val Acc: 0.8176
# Epoch 071 | Train Loss: 0.7182 | Val Loss: 0.5568 | Train Acc: 0.8399 | Val Acc: 0.8220
# Epoch 081 | Train Loss: 0.7215 | Val Loss: 0.5429 | Train Acc: 0.8469 | Val Acc: 0.8205
# Epoch 091 | Train Loss: 0.6807 | Val Loss: 0.5071 | Train Acc: 0.8527 | Val Acc: 0.8412
# Epoch 100 | Train Loss: 0.6713 | Val Loss: 0.5493 | Train Acc: 0.8436 | Val Acc: 0.8270
# Fold 1 completed in 378.46 seconds
#
# Fold 2/5
# Epoch 001 | Train Loss: 2.9267 | Val Loss: 2.1257 | Train Acc: 0.4004 | Val Acc: 0.3956
# Epoch 011 | Train Loss: 1.1903 | Val Loss: 0.9384 | Train Acc: 0.7129 | Val Acc: 0.6943
# Epoch 021 | Train Loss: 0.9954 | Val Loss: 0.7590 | Train Acc: 0.7662 | Val Acc: 0.7555
# Epoch 031 | Train Loss: 0.8903 | Val Loss: 0.7151 | Train Acc: 0.7768 | Val Acc: 0.7596
# Epoch 041 | Train Loss: 0.8306 | Val Loss: 0.6122 | Train Acc: 0.8118 | Val Acc: 0.7927
# Epoch 051 | Train Loss: 0.7866 | Val Loss: 0.5660 | Train Acc: 0.8360 | Val Acc: 0.8187
# Epoch 061 | Train Loss: 0.7362 | Val Loss: 0.5694 | Train Acc: 0.8288 | Val Acc: 0.8031
# Epoch 071 | Train Loss: 0.7166 | Val Loss: 0.5286 | Train Acc: 0.8395 | Val Acc: 0.8190
# Epoch 081 | Train Loss: 0.6946 | Val Loss: 0.5206 | Train Acc: 0.8412 | Val Acc: 0.8179
# Epoch 091 | Train Loss: 0.6671 | Val Loss: 0.4886 | Train Acc: 0.8549 | Val Acc: 0.8318
# Epoch 100 | Train Loss: 0.6510 | Val Loss: 0.4629 | Train Acc: 0.8594 | Val Acc: 0.8386
# Fold 2 completed in 366.10 seconds
#
# Fold 3/5
# Epoch 001 | Train Loss: 2.9282 | Val Loss: 2.0986 | Train Acc: 0.3705 | Val Acc: 0.3841
# Epoch 011 | Train Loss: 1.2311 | Val Loss: 0.9385 | Train Acc: 0.7097 | Val Acc: 0.7020
# Epoch 021 | Train Loss: 1.0065 | Val Loss: 0.8164 | Train Acc: 0.7441 | Val Acc: 0.7333
# Epoch 031 | Train Loss: 0.8997 | Val Loss: 0.6764 | Train Acc: 0.7909 | Val Acc: 0.7818
# Epoch 041 | Train Loss: 0.8312 | Val Loss: 0.6180 | Train Acc: 0.8076 | Val Acc: 0.7986
# Epoch 051 | Train Loss: 0.7744 | Val Loss: 0.5742 | Train Acc: 0.8169 | Val Acc: 0.8060
# Epoch 061 | Train Loss: 0.7402 | Val Loss: 0.5434 | Train Acc: 0.8305 | Val Acc: 0.8143
# Epoch 071 | Train Loss: 0.7225 | Val Loss: 0.5031 | Train Acc: 0.8416 | Val Acc: 0.8374
# Epoch 081 | Train Loss: 0.6900 | Val Loss: 0.4844 | Train Acc: 0.8464 | Val Acc: 0.8350
# Early stopping at epoch 89
# Fold 3 completed in 348.00 seconds
#
# Fold 4/5
# Epoch 001 | Train Loss: 2.9415 | Val Loss: 2.1825 | Train Acc: 0.3726 | Val Acc: 0.3537
# Epoch 011 | Train Loss: 1.1813 | Val Loss: 0.9359 | Train Acc: 0.7107 | Val Acc: 0.6980
# Epoch 021 | Train Loss: 0.9636 | Val Loss: 0.7504 | Train Acc: 0.7745 | Val Acc: 0.7613
# Epoch 031 | Train Loss: 0.8630 | Val Loss: 0.6581 | Train Acc: 0.8028 | Val Acc: 0.7903
# Epoch 041 | Train Loss: 0.7927 | Val Loss: 0.5920 | Train Acc: 0.8271 | Val Acc: 0.8004
# Epoch 051 | Train Loss: 0.7560 | Val Loss: 0.5720 | Train Acc: 0.8238 | Val Acc: 0.8140
# Epoch 061 | Train Loss: 0.7154 | Val Loss: 0.5683 | Train Acc: 0.8230 | Val Acc: 0.8092
# Early stopping at epoch 68
# Fold 4 completed in 251.42 seconds
#
# Fold 5/5
# Epoch 001 | Train Loss: 2.9295 | Val Loss: 2.2140 | Train Acc: 0.3526 | Val Acc: 0.3570
# Epoch 011 | Train Loss: 1.2329 | Val Loss: 0.9833 | Train Acc: 0.6958 | Val Acc: 0.6859
# Epoch 021 | Train Loss: 1.0240 | Val Loss: 0.7980 | Train Acc: 0.7429 | Val Acc: 0.7433
# Epoch 031 | Train Loss: 0.9251 | Val Loss: 0.6810 | Train Acc: 0.7785 | Val Acc: 0.7835
# Epoch 041 | Train Loss: 0.8562 | Val Loss: 0.6102 | Train Acc: 0.8065 | Val Acc: 0.7989
# Epoch 051 | Train Loss: 0.8066 | Val Loss: 0.5893 | Train Acc: 0.8161 | Val Acc: 0.8131
# Epoch 061 | Train Loss: 0.7638 | Val Loss: 0.5394 | Train Acc: 0.8205 | Val Acc: 0.8187
# Epoch 071 | Train Loss: 0.7354 | Val Loss: 0.5301 | Train Acc: 0.8314 | Val Acc: 0.8211
# Epoch 081 | Train Loss: 0.7175 | Val Loss: 0.4967 | Train Acc: 0.8411 | Val Acc: 0.8308
# Epoch 091 | Train Loss: 0.6694 | Val Loss: 0.4673 | Train Acc: 0.8545 | Val Acc: 0.8441
# Epoch 100 | Train Loss: 0.6640 | Val Loss: 0.5061 | Train Acc: 0.8365 | Val Acc: 0.8323
# Fold 5 completed in 373.21 seconds
#
# Cross-Validation Summary: Avg Val Accuracy: 0.8293

# %% [markdown]
# ### **9.3.Ploting k-fold cross-validation results (with SGD & Adam)**

# %%
# Plot Cross-Validation Results
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(avg_train_losses_sgd, label='Train Loss SGD')
ax1.plot(avg_val_losses_sgd, label='Val Loss SGD')
ax1.plot(avg_train_losses_adam, label='Train Loss Adam')
ax1.plot(avg_val_losses_adam, label='Val Loss Adam')
ax1.set_title('Average Loss (K-Fold)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(avg_train_accuracies_sgd, label='Train Acc SGD')
ax2.plot(avg_val_accuracies_sgd, label='Val Acc SGD')
ax2.plot(avg_train_accuracies_adam, label='Train Acc Adam')
ax2.plot(avg_val_accuracies_adam, label='Val Acc Adam')
ax2.set_title('Average Accuracy (K-Fold)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.tight_layout()
plt.savefig('kfold_loss_accuracy_sgd_adam.png')
# plt.close()

# %% [markdown]
# ## **10. Train on X_train only, use X_val for early stopping**
# This section trains the model on `X_train` (~ 16,934 samples) with `X_val` (~ 5,645 samples) for early stopping

# %% [markdown]
# ### **Case 1:  No Augmentation**

# %%
# Case 1: No Augmentation
nn = MulticlassNeuralNetwork(layer_sizes, learning_rate=best_params['learning_rate'],
                                 l2_lambda=best_params['l2_lambda'], optimizer=best_params['optimizer'])
train_losses, val_losses, train_accuracies, val_accuracies = nn.train(
    X_train, y_train_one_hot, X_val, y_val_one_hot, epochs=100,
    batch_size=best_params['batch_size'], augment=False, early_stopping=True
)
# Out:
# Epoch 001 | Train Loss: 2.0403 | Val Loss: 1.2738 | Train Acc: 0.6605 | Val Acc: 0.6291
# Epoch 011 | Train Loss: 0.2183 | Val Loss: 0.3503 | Train Acc: 0.9527 | Val Acc: 0.8943
# Epoch 021 | Train Loss: 0.1118 | Val Loss: 0.3277 | Train Acc: 0.9795 | Val Acc: 0.9017
# Epoch 031 | Train Loss: 0.0739 | Val Loss: 0.3038 | Train Acc: 0.9930 | Val Acc: 0.9163
# Early stopping at epoch 33

# %%
y_pred = nn.predict(X_test)
print("\nTest Set Classification Report (No Augmentation):")
print(classification_report(np.argmax(y_test_one_hot, axis=1), y_pred, target_names=label_encoder.classes_))

test_accuracy = np.mean(y_pred == np.argmax(y_test_one_hot, axis=1))
print(f"Test Accuracy (No Augmentation): {test_accuracy:.4f}")
# Out:
# Test Set Classification Report (No Augmentation):
#               precision    recall  f1-score   support
#
#            ⴰ       0.92      0.94      0.93       171
#            ⴱ       0.82      0.77      0.80       171
#            ⴳ       0.96      0.90      0.93       171
#           ⴳⵯ       0.98      0.98      0.98       171
#            ⴷ       0.98      0.92      0.95       171
#            ⴹ       0.75      0.87      0.80       171
#            ⴻ       0.91      0.80      0.85       171
#            ⴼ       0.93      0.96      0.95       171
#            ⴽ       0.92      0.95      0.93       170
#           ⴽⵯ       0.96      0.96      0.96       170
#            ⵀ       0.84      0.95      0.89       171
#            ⵃ       0.97      0.92      0.95       171
#            ⵄ       0.94      0.99      0.97       171
#            ⵅ       0.95      0.95      0.95       171
#            ⵇ       0.94      0.92      0.93       171
#            ⵉ       0.91      0.92      0.92       170
#            ⵊ       0.90      0.92      0.91       171
#            ⵍ       0.95      0.88      0.91       170
#            ⵎ       0.94      0.90      0.92       171
#            ⵏ       0.94      0.91      0.93       171
#            ⵓ       0.81      0.89      0.85       171
#            ⵔ       0.90      0.83      0.86       171
#            ⵕ       0.82      0.95      0.88       171
#            ⵖ       0.95      0.96      0.96       171
#            ⵙ       0.81      0.78      0.79       171
#            ⵚ       0.91      0.89      0.90       171
#            ⵛ       0.90      0.92      0.91       170
#            ⵜ       0.95      0.94      0.95       171
#            ⵟ       0.92      0.74      0.82       171
#            ⵡ       0.90      0.96      0.93       171
#            ⵢ       0.94      0.97      0.96       171
#            ⵣ       0.93      0.83      0.88       170
#            ⵥ       0.84      0.93      0.88       171
#
#     accuracy                           0.91      5637
#    macro avg       0.91      0.91      0.91      5637
# weighted avg       0.91      0.91      0.91      5637
#
# Test Accuracy (No Augmentation): 0.9069

# %%
cm = confusion_matrix(np.argmax(y_test_one_hot, axis=1), y_pred)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix (No Augmentation)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_no_aug.png')
# plt.close()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(train_losses, label='Train Loss')
ax1.plot(val_losses, label='Validation Loss')
ax1.set_title('Loss Curve (No Augmentation)')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(train_accuracies, label='Train Accuracy')
ax2.plot(val_accuracies, label='Validation Accuracy')
ax2.set_title('Accuracy Curve (No Augmentation)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.tight_layout()
plt.savefig('loss_accuracy_no_aug.png')
# plt.close()

# %% [markdown]
# ### **Case 2:  With Augmentation**

# %%
# Case 2: With Augmentation
nn_aug = MulticlassNeuralNetwork(layer_sizes, learning_rate=best_params['learning_rate'],
                                     l2_lambda=best_params['l2_lambda'], optimizer=best_params['optimizer'])
train_losses_aug, val_losses_aug, train_accuracies_aug, val_accuracies_aug = nn_aug.train(
    X_train, y_train_one_hot, X_val, y_val_one_hot, epochs=100,
    batch_size=best_params['batch_size'], augment=True, early_stopping=True
)
# Out:
# Epoch 001 | Train Loss: 2.8113 | Val Loss: 2.0005 | Train Acc: 0.4410 | Val Acc: 0.4305
# Epoch 011 | Train Loss: 1.1272 | Val Loss: 0.8969 | Train Acc: 0.7183 | Val Acc: 0.7137
# Epoch 021 | Train Loss: 0.9390 | Val Loss: 0.7218 | Train Acc: 0.7770 | Val Acc: 0.7674
# Epoch 031 | Train Loss: 0.8262 | Val Loss: 0.6336 | Train Acc: 0.8048 | Val Acc: 0.7974
# Epoch 041 | Train Loss: 0.7841 | Val Loss: 0.6032 | Train Acc: 0.8198 | Val Acc: 0.8049
# Epoch 051 | Train Loss: 0.7349 | Val Loss: 0.5778 | Train Acc: 0.8196 | Val Acc: 0.8017
# Epoch 061 | Train Loss: 0.7042 | Val Loss: 0.5214 | Train Acc: 0.8378 | Val Acc: 0.8254
# Epoch 071 | Train Loss: 0.6943 | Val Loss: 0.5589 | Train Acc: 0.8330 | Val Acc: 0.8155
# Epoch 081 | Train Loss: 0.6562 | Val Loss: 0.5056 | Train Acc: 0.8403 | Val Acc: 0.8301
# Epoch 091 | Train Loss: 0.6459 | Val Loss: 0.5323 | Train Acc: 0.8348 | Val Acc: 0.8214
# Epoch 100 | Train Loss: 0.6201 | Val Loss: 0.4768 | Train Acc: 0.8511 | Val Acc: 0.8398

# %%
y_pred_aug = nn_aug.predict(X_test)
print("\nTest Set Classification Report (With Augmentation ):")
print(classification_report(np.argmax(y_test_one_hot, axis=1), y_pred_aug, target_names=label_encoder.classes_))

test_accuracy_aug = np.mean(y_pred_aug == np.argmax(y_test_one_hot, axis=1))
print(f"Test Accuracy (With Augmentation ): {test_accuracy_aug:.4f}")
# Out:
# Test Set Classification Report (With Augmentation ):
#               precision    recall  f1-score   support
#
#            ⴰ       0.85      0.98      0.91       171
#            ⴱ       0.53      0.80      0.64       171
#            ⴳ       0.91      0.91      0.91       171
#           ⴳⵯ       0.91      0.96      0.93       171
#            ⴷ       0.93      0.91      0.92       171
#            ⴹ       0.60      0.84      0.70       171
#            ⴻ       0.74      0.70      0.72       171
#            ⴼ       0.93      0.91      0.92       171
#            ⴽ       0.88      0.91      0.89       170
#           ⴽⵯ       0.91      0.88      0.90       170
#            ⵀ       0.97      0.80      0.87       171
#            ⵃ       0.93      0.98      0.95       171
#            ⵄ       0.93      0.89      0.91       171
#            ⵅ       0.92      0.89      0.91       171
#            ⵇ       0.82      0.84      0.83       171
#            ⵉ       0.86      0.73      0.79       170
#            ⵊ       0.75      0.84      0.79       171
#            ⵍ       0.93      0.88      0.90       170
#            ⵎ       0.89      0.95      0.92       171
#            ⵏ       0.84      0.88      0.86       171
#            ⵓ       0.78      0.78      0.78       171
#            ⵔ       0.76      0.83      0.79       171
#            ⵕ       0.93      0.75      0.83       171
#            ⵖ       0.95      0.89      0.92       171
#            ⵙ       0.69      0.27      0.39       171
#            ⵚ       0.95      0.84      0.89       171
#            ⵛ       0.86      0.92      0.89       170
#            ⵜ       0.96      0.93      0.94       171
#            ⵟ       0.68      0.60      0.64       171
#            ⵡ       0.89      0.93      0.91       171
#            ⵢ       0.85      0.98      0.91       171
#            ⵣ       0.76      0.81      0.78       170
#            ⵥ       0.84      0.67      0.75       171
#
#     accuracy                           0.84      5637
#    macro avg       0.85      0.84      0.84      5637
# weighted avg       0.85      0.84      0.84      5637
#
# Test Accuracy (With Augmentation ): 0.8395

# %%
cm_aug = confusion_matrix(np.argmax(y_test_one_hot, axis=1), y_pred_aug)
plt.figure(figsize=(12, 10))
sns.heatmap(cm_aug, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix (With Augmentation )')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_with_aug.png')
# plt.close()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(train_losses_aug, label='Train Loss')
ax1.plot(val_losses_aug, label='Validation Loss')
ax1.set_title('Loss Curve (With Augmentation )')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(train_accuracies_aug, label='Train Accuracy')
ax2.plot(val_accuracies_aug, label='Validation Accuracy')
ax2.set_title('Accuracy Curve (With Augmentation )')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.tight_layout()
plt.savefig('loss_accuracy_with_aug.png')
# plt.close()

# %%
# # Generate Markdown:
# print(f"""## 11. Results Summary
# - Best parameters: {best_params}
# - Best validation accuracy: {best_val_accuracy:.2%}

# - **Approach**:
#   - Test accuracy (No Augmentation): {test_accuracy:.2%}
#   - Test accuracy (With Augmentation): {test_accuracy_aug:.2%}
# """)

# %% [markdown]
# ## 11. Results Summary
# - Best parameters: {'learning_rate': 0.001, 'l2_lambda': 0.001, 'batch_size': 32, 'optimizer': 'adam'}
# - Best validation accuracy: 83.70%
#
# - **Approach**:
#   - Test accuracy (No Augmentation): 90.69%
#   - Test accuracy (With Augmentation): 83.95%
